# %%
#HEX to DECIMAL
import numpy as np
file = open("/home/saklain/CryptoLab/hex.txt", "r")
fileout = open("/home/saklain/hexout.txt","w") 


#hx = input()
#print(int(hx,16))

for line in file:
    #print(line)
    p=int(line,16)
    #print(p)
    fileout.write(str(p)+"\n")

fileout.close()
file.close()

# %%
#Ceaser Cipher

file = open("/home/saklain/CryptoLab/ceaser.txt","r")
fileout = open("/home/saklain/CryptoLab/ceaout.txt","w")

for line in file:
    st=""
    for i in line:
        if(i==' '):
            continue
        if(i=='\n'):
            print("newline")
            continue
        #print(i)
        charid = (ord(i)+3)%123
        if(charid<97):
            charid+=97
        
        st= st+chr(charid)
    
    #print(st)
    fileout.write(st+"\n")
    
    
file.close()

fileout.close()
# Out:
# newline

# %%
#ENCRYPTION
fileout = open("/home/saklain/CryptoLab/cip.txt","w")

file = open("key.txt","r") 
key=file.readline()[:-1]

idx=0

with open("/home/saklain/CryptoLab/veg_in.txt","r") as f:
    while True:
        ch = f.read(1)
        if not ch:
              print("End of file")
              break
        if ch=='\n':
            fileout.write(str('\n'))
            continue
        if ch==' ':
            fileout.write(str(' '))
            continue

        plainidx = ord(ch)
        if(plainidx>90):
            plainidx-=6
        plainidx-=65
        
        #print(key[idx])
        keyidx = ord(key[idx])
        if(keyidx>90):
            keyidx-=6
        keyidx-=65
        
        temp = idx
        
        idx+=1
        if(idx==len(key)):
            idx=0
            
        #print(ch,ord(ch),plainidx)
        newidx = (plainidx+keyidx)%52
        
        
                                
        cipidx = newidx+65
        
        if(cipidx>90):
            cipidx+=6
        
        print(ch,"=",ord(ch), "(",plainidx,")  key,",key[temp],"=",ord(key[temp]),"(",keyidx,")  modval =",newidx, "  cipher,",chr(cipidx),"=",cipidx)
        
        
        fileout.write(str(chr(cipidx)))
        
fileout.close()
# Out:
# W = 87 ( 22 )  key, a = 97 ( 26 )  modval = 48   cipher, w = 119
# i = 105 ( 34 )  key, A = 65 ( 0 )  modval = 34   cipher, i = 105
# F = 70 ( 5 )  key, J = 74 ( 9 )  modval = 14   cipher, O = 79
# i = 105 ( 34 )  key, t = 116 ( 45 )  modval = 27   cipher, b = 98
# o = 111 ( 40 )  key, n = 110 ( 39 )  modval = 27   cipher, b = 98
# r = 114 ( 43 )  key, L = 76 ( 11 )  modval = 2   cipher, C = 67
# W = 87 ( 22 )  key, o = 111 ( 40 )  modval = 10   cipher, K = 75
# i = 105 ( 34 )  key, p = 112 ( 41 )  modval = 23   cipher, X = 88
# F = 70 ( 5 )  key, q = 113 ( 42 )  modval = 47   cipher, v = 118
# i = 105 ( 34 )  key, F = 70 ( 5 )  modval = 39   cipher, n = 110
# i = 105 ( 34 )  key, y = 121 ( 50 )  modval = 32   cipher, g = 103
# s = 115 ( 44 )  key, v = 118 ( 47 )  modval = 39   cipher, n = 110
# t = 116 ( 45 )  key, D = 68 ( 3 )  modval = 48   cipher, w = 119
# e = 101 ( 30 )  key, a = 97 ( 26 )  modval = 4   cipher, E = 69
# c = 99 ( 28 )  key, A = 65 ( 0 )  modval = 28   cipher, c = 99
# h = 104 ( 33 )  key, J = 74 ( 9 )  modval = 42   cipher, q = 113
# n = 110 ( 39 )  key, t = 116 ( 45 )  modval = 32   cipher, g = 103
# o = 111 ( 40 )  key, n = 110 ( 39 )  modval = 27   cipher, b = 98
# l = 108 ( 37 )  key, L = 76 ( 11 )  modval = 48   cipher, w = 119
# o = 111 ( 40 )  key, o = 111 ( 40 )  modval = 28   cipher, c = 99
# g = 103 ( 32 )  key, p = 112 ( 41 )  modval = 21   cipher, V = 86
# y = 121 ( 50 )  key, q = 113 ( 42 )  modval = 40   cipher, o = 111
# f = 102 ( 31 )  key, F = 70 ( 5 )  modval = 36   cipher, k = 107
# o = 111 ( 40 )  key, y = 121 ( 50 )  modval = 38   cipher, m = 109
# r = 114 ( 43 )  key, v = 118 ( 47 )  modval = 38   cipher, m = 109
# r = 114 ( 43 )  key, D = 68 ( 3 )  modval = 46   cipher, u = 117
# a = 97 ( 26 )  key, a = 97 ( 26 )  modval = 0   cipher, A = 65
# d = 100 ( 29 )  key, A = 65 ( 0 )  modval = 29   cipher, d = 100
# i = 105 ( 34 )  key, J = 74 ( 9 )  modval = 43   cipher, r = 114
# o = 111 ( 40 )  key, t = 116 ( 45 )  modval = 33   cipher, h = 104
# w = 119 ( 48 )  key, n = 110 ( 39 )  modval = 35   cipher, j = 106
# i = 105 ( 34 )  key, L = 76 ( 11 )  modval = 45   cipher, t = 116
# r = 114 ( 43 )  key, o = 111 ( 40 )  modval = 31   cipher, f = 102
# e = 101 ( 30 )  key, p = 112 ( 41 )  modval = 19   cipher, T = 84
# l = 108 ( 37 )  key, q = 113 ( 42 )  modval = 27   cipher, b = 98
# e = 101 ( 30 )  key, F = 70 ( 5 )  modval = 35   cipher, j = 106
# s = 115 ( 44 )  key, y = 121 ( 50 )  modval = 42   cipher, q = 113
# s = 115 ( 44 )  key, v = 118 ( 47 )  modval = 39   cipher, n = 110
# l = 108 ( 37 )  key, D = 68 ( 3 )  modval = 40   cipher, o = 111
# o = 111 ( 40 )  key, a = 97 ( 26 )  modval = 14   cipher, O = 79
# c = 99 ( 28 )  key, A = 65 ( 0 )  modval = 28   cipher, c = 99
# a = 97 ( 26 )  key, J = 74 ( 9 )  modval = 35   cipher, j = 106
# l = 108 ( 37 )  key, t = 116 ( 45 )  modval = 30   cipher, e = 101
# a = 97 ( 26 )  key, n = 110 ( 39 )  modval = 13   cipher, N = 78
# r = 114 ( 43 )  key, L = 76 ( 11 )  modval = 2   cipher, C = 67
# e = 101 ( 30 )  key, o = 111 ( 40 )  modval = 18   cipher, S = 83
# a = 97 ( 26 )  key, p = 112 ( 41 )  modval = 15   cipher, P = 80
# n = 110 ( 39 )  key, q = 113 ( 42 )  modval = 29   cipher, d = 100
# e = 101 ( 30 )  key, F = 70 ( 5 )  modval = 35   cipher, j = 106
# t = 116 ( 45 )  key, y = 121 ( 50 )  modval = 43   cipher, r = 114
# w = 119 ( 48 )  key, v = 118 ( 47 )  modval = 43   cipher, r = 114
# o = 111 ( 40 )  key, D = 68 ( 3 )  modval = 43   cipher, r = 114
# r = 114 ( 43 )  key, a = 97 ( 26 )  modval = 17   cipher, R = 82
# k = 107 ( 36 )  key, A = 65 ( 0 )  modval = 36   cipher, k = 107
# i = 105 ( 34 )  key, J = 74 ( 9 )  modval = 43   cipher, r = 114
# n = 110 ( 39 )  key, t = 116 ( 45 )  modval = 32   cipher, g = 103
# g = 103 ( 32 )  key, n = 110 ( 39 )  modval = 19   cipher, T = 84
# o = 111 ( 40 )  key, L = 76 ( 11 )  modval = 51   cipher, z = 122
# f = 102 ( 31 )  key, o = 111 ( 40 )  modval = 19   cipher, T = 84
# d = 100 ( 29 )  key, p = 112 ( 41 )  modval = 18   cipher, S = 83
# e = 101 ( 30 )  key, q = 113 ( 42 )  modval = 20   cipher, U = 85
# v = 118 ( 47 )  key, F = 70 ( 5 )  modval = 0   cipher, A = 65
# i = 105 ( 34 )  key, y = 121 ( 50 )  modval = 32   cipher, g = 103
# c = 99 ( 28 )  key, v = 118 ( 47 )  modval = 23   cipher, X = 88
# e = 101 ( 30 )  key, D = 68 ( 3 )  modval = 33   cipher, h = 104
# s = 115 ( 44 )  key, a = 97 ( 26 )  modval = 18   cipher, S = 83
# b = 98 ( 27 )  key, A = 65 ( 0 )  modval = 27   cipher, b = 98
# a = 97 ( 26 )  key, J = 74 ( 9 )  modval = 35   cipher, j = 106
# s = 115 ( 44 )  key, t = 116 ( 45 )  modval = 37   cipher, l = 108
# e = 101 ( 30 )  key, n = 110 ( 39 )  modval = 17   cipher, R = 82
# d = 100 ( 29 )  key, L = 76 ( 11 )  modval = 40   cipher, o = 111
# o = 111 ( 40 )  key, o = 111 ( 40 )  modval = 28   cipher, c = 99
# n = 110 ( 39 )  key, p = 112 ( 41 )  modval = 28   cipher, c = 99
# t = 116 ( 45 )  key, q = 113 ( 42 )  modval = 35   cipher, j = 106
# h = 104 ( 33 )  key, F = 70 ( 5 )  modval = 38   cipher, m = 109
# e = 101 ( 30 )  key, y = 121 ( 50 )  modval = 28   cipher, c = 99
# I = 73 ( 8 )  key, v = 118 ( 47 )  modval = 3   cipher, D = 68
# E = 69 ( 4 )  key, D = 68 ( 3 )  modval = 7   cipher, H = 72
# E = 69 ( 4 )  key, a = 97 ( 26 )  modval = 30   cipher, e = 101
# E = 69 ( 4 )  key, A = 65 ( 0 )  modval = 4   cipher, E = 69
# s = 115 ( 44 )  key, J = 74 ( 9 )  modval = 1   cipher, B = 66
# t = 116 ( 45 )  key, t = 116 ( 45 )  modval = 38   cipher, m = 109
# a = 97 ( 26 )  key, n = 110 ( 39 )  modval = 13   cipher, N = 78
# n = 110 ( 39 )  key, L = 76 ( 11 )  modval = 50   cipher, y = 121
# d = 100 ( 29 )  key, o = 111 ( 40 )  modval = 17   cipher, R = 82
# a = 97 ( 26 )  key, p = 112 ( 41 )  modval = 15   cipher, P = 80
# r = 114 ( 43 )  key, q = 113 ( 42 )  modval = 33   cipher, h = 104
# d = 100 ( 29 )  key, F = 70 ( 5 )  modval = 34   cipher, i = 105
# s = 115 ( 44 )  key, y = 121 ( 50 )  modval = 42   cipher, q = 113
# W = 87 ( 22 )  key, v = 118 ( 47 )  modval = 17   cipher, R = 82
# i = 105 ( 34 )  key, D = 68 ( 3 )  modval = 37   cipher, l = 108
# F = 70 ( 5 )  key, a = 97 ( 26 )  modval = 31   cipher, f = 102
# i = 105 ( 34 )  key, A = 65 ( 0 )  modval = 34   cipher, i = 105
# i = 105 ( 34 )  key, J = 74 ( 9 )  modval = 43   cipher, r = 114
# s = 115 ( 44 )  key, t = 116 ( 45 )  modval = 37   cipher, l = 108
# a = 97 ( 26 )  key, n = 110 ( 39 )  modval = 13   cipher, N = 78
# t = 116 ( 45 )  key, L = 76 ( 11 )  modval = 4   cipher, E = 69
# r = 114 ( 43 )  key, o = 111 ( 40 )  modval = 31   cipher, f = 102
# a = 97 ( 26 )  key, p = 112 ( 41 )  modval = 15   cipher, P = 80
# d = 100 ( 29 )  key, q = 113 ( 42 )  modval = 19   cipher, T = 84
# e = 101 ( 30 )  key, F = 70 ( 5 )  modval = 35   cipher, j = 106
# m = 109 ( 38 )  key, y = 121 ( 50 )  modval = 36   cipher, k = 107
# a = 97 ( 26 )  key, v = 118 ( 47 )  modval = 21   cipher, V = 86
# r = 114 ( 43 )  key, D = 68 ( 3 )  modval = 46   cipher, u = 117
# k = 107 ( 36 )  key, a = 97 ( 26 )  modval = 10   cipher, K = 75
# o = 111 ( 40 )  key, A = 65 ( 0 )  modval = 40   cipher, o = 111
# f = 102 ( 31 )  key, J = 74 ( 9 )  modval = 40   cipher, o = 111
# t = 116 ( 45 )  key, t = 116 ( 45 )  modval = 38   cipher, m = 109
# h = 104 ( 33 )  key, n = 110 ( 39 )  modval = 20   cipher, U = 85
# e = 101 ( 30 )  key, L = 76 ( 11 )  modval = 41   cipher, p = 112
# W = 87 ( 22 )  key, o = 111 ( 40 )  modval = 10   cipher, K = 75
# i = 105 ( 34 )  key, p = 112 ( 41 )  modval = 23   cipher, X = 88
# F = 70 ( 5 )  key, q = 113 ( 42 )  modval = 47   cipher, v = 118
# i = 105 ( 34 )  key, F = 70 ( 5 )  modval = 39   cipher, n = 110
# A = 65 ( 0 )  key, y = 121 ( 50 )  modval = 50   cipher, y = 121
# l = 108 ( 37 )  key, v = 118 ( 47 )  modval = 32   cipher, g = 103
# l = 108 ( 37 )  key, D = 68 ( 3 )  modval = 40   cipher, o = 111
# i = 105 ( 34 )  key, a = 97 ( 26 )  modval = 8   cipher, I = 73
# a = 97 ( 26 )  key, A = 65 ( 0 )  modval = 26   cipher, a = 97
# n = 110 ( 39 )  key, J = 74 ( 9 )  modval = 48   cipher, w = 119
# c = 99 ( 28 )  key, t = 116 ( 45 )  modval = 21   cipher, V = 86
# e = 101 ( 30 )  key, n = 110 ( 39 )  modval = 17   cipher, R = 82
# W = 87 ( 22 )  key, L = 76 ( 11 )  modval = 33   cipher, h = 104
# i = 105 ( 34 )  key, o = 111 ( 40 )  modval = 22   cipher, W = 87
# k = 107 ( 36 )  key, p = 112 ( 41 )  modval = 25   cipher, Z = 90
# i = 105 ( 34 )  key, q = 113 ( 42 )  modval = 24   cipher, Y = 89
# p = 112 ( 41 )  key, F = 70 ( 5 )  modval = 46   cipher, u = 117
# e = 101 ( 30 )  key, y = 121 ( 50 )  modval = 28   cipher, c = 99
# d = 100 ( 29 )  key, v = 118 ( 47 )  modval = 24   cipher, Y = 89
# i = 105 ( 34 )  key, D = 68 ( 3 )  modval = 37   cipher, l = 108
# a = 97 ( 26 )  key, a = 97 ( 26 )  modval = 0   cipher, A = 65
# i = 105 ( 34 )  key, A = 65 ( 0 )  modval = 34   cipher, i = 105
# s = 115 ( 44 )  key, J = 74 ( 9 )  modval = 1   cipher, B = 66
# a = 97 ( 26 )  key, t = 116 ( 45 )  modval = 19   cipher, T = 84
# m = 109 ( 38 )  key, n = 110 ( 39 )  modval = 25   cipher, Z = 90
# u = 117 ( 46 )  key, L = 76 ( 11 )  modval = 5   cipher, F = 70
# l = 108 ( 37 )  key, o = 111 ( 40 )  modval = 25   cipher, Z = 90
# t = 116 ( 45 )  key, p = 112 ( 41 )  modval = 34   cipher, i = 105
# i = 105 ( 34 )  key, q = 113 ( 42 )  modval = 24   cipher, Y = 89
# l = 108 ( 37 )  key, F = 70 ( 5 )  modval = 42   cipher, q = 113
# i = 105 ( 34 )  key, y = 121 ( 50 )  modval = 32   cipher, g = 103
# n = 110 ( 39 )  key, v = 118 ( 47 )  modval = 34   cipher, i = 105
# g = 103 ( 32 )  key, D = 68 ( 3 )  modval = 35   cipher, j = 106
# u = 117 ( 46 )  key, a = 97 ( 26 )  modval = 20   cipher, U = 85
# a = 97 ( 26 )  key, A = 65 ( 0 )  modval = 26   cipher, a = 97
# l = 108 ( 37 )  key, J = 74 ( 9 )  modval = 46   cipher, u = 117
# w = 119 ( 48 )  key, t = 116 ( 45 )  modval = 41   cipher, p = 112
# e = 101 ( 30 )  key, n = 110 ( 39 )  modval = 17   cipher, R = 82
# b = 98 ( 27 )  key, L = 76 ( 11 )  modval = 38   cipher, m = 109
# b = 98 ( 27 )  key, o = 111 ( 40 )  modval = 15   cipher, P = 80
# a = 97 ( 26 )  key, p = 112 ( 41 )  modval = 15   cipher, P = 80
# s = 115 ( 44 )  key, q = 113 ( 42 )  modval = 34   cipher, i = 105
# e = 101 ( 30 )  key, F = 70 ( 5 )  modval = 35   cipher, j = 106
# d = 100 ( 29 )  key, y = 121 ( 50 )  modval = 27   cipher, b = 98
# f = 102 ( 31 )  key, v = 118 ( 47 )  modval = 26   cipher, a = 97
# r = 114 ( 43 )  key, D = 68 ( 3 )  modval = 46   cipher, u = 117
# e = 101 ( 30 )  key, a = 97 ( 26 )  modval = 4   cipher, E = 69
# e = 101 ( 30 )  key, A = 65 ( 0 )  modval = 30   cipher, e = 101
# e = 101 ( 30 )  key, J = 74 ( 9 )  modval = 39   cipher, n = 110
# n = 110 ( 39 )  key, t = 116 ( 45 )  modval = 32   cipher, g = 103
# c = 99 ( 28 )  key, n = 110 ( 39 )  modval = 15   cipher, P = 80
# y = 121 ( 50 )  key, L = 76 ( 11 )  modval = 9   cipher, J = 74
# c = 99 ( 28 )  key, o = 111 ( 40 )  modval = 16   cipher, Q = 81
# l = 108 ( 37 )  key, p = 112 ( 41 )  modval = 26   cipher, a = 97
# o = 111 ( 40 )  key, q = 113 ( 42 )  modval = 30   cipher, e = 101
# p = 112 ( 41 )  key, F = 70 ( 5 )  modval = 46   cipher, u = 117
# e = 101 ( 30 )  key, y = 121 ( 50 )  modval = 28   cipher, c = 99
# d = 100 ( 29 )  key, v = 118 ( 47 )  modval = 24   cipher, Y = 89
# i = 105 ( 34 )  key, D = 68 ( 3 )  modval = 37   cipher, l = 108
# a = 97 ( 26 )  key, a = 97 ( 26 )  modval = 0   cipher, A = 65
# b = 98 ( 27 )  key, A = 65 ( 0 )  modval = 27   cipher, b = 98
# a = 97 ( 26 )  key, J = 74 ( 9 )  modval = 35   cipher, j = 106
# s = 115 ( 44 )  key, t = 116 ( 45 )  modval = 37   cipher, l = 108
# e = 101 ( 30 )  key, n = 110 ( 39 )  modval = 17   cipher, R = 82
# d = 100 ( 29 )  key, L = 76 ( 11 )  modval = 40   cipher, o = 111
# o = 111 ( 40 )  key, o = 111 ( 40 )  modval = 28   cipher, c = 99
# n = 110 ( 39 )  key, p = 112 ( 41 )  modval = 28   cipher, c = 99
# a = 97 ( 26 )  key, q = 113 ( 42 )  modval = 16   cipher, Q = 81
# m = 109 ( 38 )  key, F = 70 ( 5 )  modval = 43   cipher, r = 114
# o = 111 ( 40 )  key, y = 121 ( 50 )  modval = 38   cipher, m = 109
# d = 100 ( 29 )  key, v = 118 ( 47 )  modval = 24   cipher, Y = 89
# e = 101 ( 30 )  key, D = 68 ( 3 )  modval = 33   cipher, h = 104
# l = 108 ( 37 )  key, a = 97 ( 26 )  modval = 11   cipher, L = 76
# o = 111 ( 40 )  key, A = 65 ( 0 )  modval = 40   cipher, o = 111
# f = 102 ( 31 )  key, J = 74 ( 9 )  modval = 40   cipher, o = 111
# o = 111 ( 40 )  key, t = 116 ( 45 )  modval = 33   cipher, h = 104
# p = 112 ( 41 )  key, n = 110 ( 39 )  modval = 28   cipher, c = 99
# e = 101 ( 30 )  key, L = 76 ( 11 )  modval = 41   cipher, p = 112
# n = 110 ( 39 )  key, o = 111 ( 40 )  modval = 27   cipher, b = 98
# l = 108 ( 37 )  key, p = 112 ( 41 )  modval = 26   cipher, a = 97
# y = 121 ( 50 )  key, q = 113 ( 42 )  modval = 40   cipher, o = 111
# e = 101 ( 30 )  key, F = 70 ( 5 )  modval = 35   cipher, j = 106
# d = 100 ( 29 )  key, y = 121 ( 50 )  modval = 27   cipher, b = 98
# i = 105 ( 34 )  key, v = 118 ( 47 )  modval = 29   cipher, d = 100
# t = 116 ( 45 )  key, D = 68 ( 3 )  modval = 48   cipher, w = 119
# a = 97 ( 26 )  key, a = 97 ( 26 )  modval = 0   cipher, A = 65
# b = 98 ( 27 )  key, A = 65 ( 0 )  modval = 27   cipher, b = 98
# l = 108 ( 37 )  key, J = 74 ( 9 )  modval = 46   cipher, u = 117
# e = 101 ( 30 )  key, t = 116 ( 45 )  modval = 23   cipher, X = 88
# c = 99 ( 28 )  key, n = 110 ( 39 )  modval = 15   cipher, P = 80
# o = 111 ( 40 )  key, L = 76 ( 11 )  modval = 51   cipher, z = 122
# n = 110 ( 39 )  key, o = 111 ( 40 )  modval = 27   cipher, b = 98
# t = 116 ( 45 )  key, p = 112 ( 41 )  modval = 34   cipher, i = 105
# e = 101 ( 30 )  key, q = 113 ( 42 )  modval = 20   cipher, U = 85
# n = 110 ( 39 )  key, F = 70 ( 5 )  modval = 44   cipher, s = 115
# t = 116 ( 45 )  key, y = 121 ( 50 )  modval = 43   cipher, r = 114
# I = 73 ( 8 )  key, v = 118 ( 47 )  modval = 3   cipher, D = 68
# t = 116 ( 45 )  key, D = 68 ( 3 )  modval = 48   cipher, w = 119
# i = 105 ( 34 )  key, a = 97 ( 26 )  modval = 8   cipher, I = 73
# s = 115 ( 44 )  key, A = 65 ( 0 )  modval = 44   cipher, s = 115
# t = 116 ( 45 )  key, J = 74 ( 9 )  modval = 2   cipher, C = 67
# h = 104 ( 33 )  key, t = 116 ( 45 )  modval = 26   cipher, a = 97
# e = 101 ( 30 )  key, n = 110 ( 39 )  modval = 17   cipher, R = 82
# l = 108 ( 37 )  key, L = 76 ( 11 )  modval = 48   cipher, w = 119
# a = 97 ( 26 )  key, o = 111 ( 40 )  modval = 14   cipher, O = 79
# r = 114 ( 43 )  key, p = 112 ( 41 )  modval = 32   cipher, g = 103
# g = 103 ( 32 )  key, q = 113 ( 42 )  modval = 22   cipher, W = 87
# e = 101 ( 30 )  key, F = 70 ( 5 )  modval = 35   cipher, j = 106
# s = 115 ( 44 )  key, y = 121 ( 50 )  modval = 42   cipher, q = 113
# t = 116 ( 45 )  key, v = 118 ( 47 )  modval = 40   cipher, o = 111
# a = 97 ( 26 )  key, D = 68 ( 3 )  modval = 29   cipher, d = 100
# n = 110 ( 39 )  key, a = 97 ( 26 )  modval = 13   cipher, N = 78
# d = 100 ( 29 )  key, A = 65 ( 0 )  modval = 29   cipher, d = 100
# m = 109 ( 38 )  key, J = 74 ( 9 )  modval = 47   cipher, v = 118
# o = 111 ( 40 )  key, t = 116 ( 45 )  modval = 33   cipher, h = 104
# s = 115 ( 44 )  key, n = 110 ( 39 )  modval = 31   cipher, f = 102
# t = 116 ( 45 )  key, L = 76 ( 11 )  modval = 4   cipher, E = 69
# p = 112 ( 41 )  key, o = 111 ( 40 )  modval = 29   cipher, d = 100
# o = 111 ( 40 )  key, p = 112 ( 41 )  modval = 29   cipher, d = 100
# p = 112 ( 41 )  key, q = 113 ( 42 )  modval = 31   cipher, f = 102
# u = 117 ( 46 )  key, F = 70 ( 5 )  modval = 51   cipher, z = 122
# l = 108 ( 37 )  key, y = 121 ( 50 )  modval = 35   cipher, j = 106
# a = 97 ( 26 )  key, v = 118 ( 47 )  modval = 21   cipher, V = 86
# r = 114 ( 43 )  key, D = 68 ( 3 )  modval = 46   cipher, u = 117
# g = 103 ( 32 )  key, a = 97 ( 26 )  modval = 6   cipher, G = 71
# e = 101 ( 30 )  key, A = 65 ( 0 )  modval = 30   cipher, e = 101
# n = 110 ( 39 )  key, J = 74 ( 9 )  modval = 48   cipher, w = 119
# e = 101 ( 30 )  key, t = 116 ( 45 )  modval = 23   cipher, X = 88
# r = 114 ( 43 )  key, n = 110 ( 39 )  modval = 30   cipher, e = 101
# a = 97 ( 26 )  key, L = 76 ( 11 )  modval = 37   cipher, l = 108
# l = 108 ( 37 )  key, o = 111 ( 40 )  modval = 25   cipher, Z = 90
# r = 114 ( 43 )  key, p = 112 ( 41 )  modval = 32   cipher, g = 103
# e = 101 ( 30 )  key, q = 113 ( 42 )  modval = 20   cipher, U = 85
# f = 102 ( 31 )  key, F = 70 ( 5 )  modval = 36   cipher, k = 107
# e = 101 ( 30 )  key, y = 121 ( 50 )  modval = 28   cipher, c = 99
# r = 114 ( 43 )  key, v = 118 ( 47 )  modval = 38   cipher, m = 109
# e = 101 ( 30 )  key, D = 68 ( 3 )  modval = 33   cipher, h = 104
# n = 110 ( 39 )  key, a = 97 ( 26 )  modval = 13   cipher, N = 78
# c = 99 ( 28 )  key, A = 65 ( 0 )  modval = 28   cipher, c = 99
# e = 101 ( 30 )  key, J = 74 ( 9 )  modval = 39   cipher, n = 110
# w = 119 ( 48 )  key, t = 116 ( 45 )  modval = 41   cipher, p = 112
# o = 111 ( 40 )  key, n = 110 ( 39 )  modval = 27   cipher, b = 98
# r = 114 ( 43 )  key, L = 76 ( 11 )  modval = 2   cipher, C = 67
# k = 107 ( 36 )  key, o = 111 ( 40 )  modval = 24   cipher, Y = 89
# o = 111 ( 40 )  key, p = 112 ( 41 )  modval = 29   cipher, d = 100
# n = 110 ( 39 )  key, q = 113 ( 42 )  modval = 29   cipher, d = 100
# t = 116 ( 45 )  key, F = 70 ( 5 )  modval = 50   cipher, y = 121
# h = 104 ( 33 )  key, y = 121 ( 50 )  modval = 31   cipher, f = 102
# e = 101 ( 30 )  key, v = 118 ( 47 )  modval = 25   cipher, Z = 90
# I = 73 ( 8 )  key, D = 68 ( 3 )  modval = 11   cipher, L = 76
# n = 110 ( 39 )  key, a = 97 ( 26 )  modval = 13   cipher, N = 78
# t = 116 ( 45 )  key, A = 65 ( 0 )  modval = 45   cipher, t = 116
# e = 101 ( 30 )  key, J = 74 ( 9 )  modval = 39   cipher, n = 110
# r = 114 ( 43 )  key, t = 116 ( 45 )  modval = 36   cipher, k = 107
# n = 110 ( 39 )  key, n = 110 ( 39 )  modval = 26   cipher, a = 97
# e = 101 ( 30 )  key, L = 76 ( 11 )  modval = 41   cipher, p = 112
# t = 116 ( 45 )  key, o = 111 ( 40 )  modval = 33   cipher, h = 104
# a = 97 ( 26 )  key, p = 112 ( 41 )  modval = 15   cipher, P = 80
# n = 110 ( 39 )  key, q = 113 ( 42 )  modval = 29   cipher, d = 100
# d = 100 ( 29 )  key, F = 70 ( 5 )  modval = 34   cipher, i = 105
# i = 105 ( 34 )  key, y = 121 ( 50 )  modval = 32   cipher, g = 103
# s = 115 ( 44 )  key, v = 118 ( 47 )  modval = 39   cipher, n = 110
# o = 111 ( 40 )  key, D = 68 ( 3 )  modval = 43   cipher, r = 114
# n = 110 ( 39 )  key, a = 97 ( 26 )  modval = 13   cipher, N = 78
# e = 101 ( 30 )  key, A = 65 ( 0 )  modval = 30   cipher, e = 101
# o = 111 ( 40 )  key, J = 74 ( 9 )  modval = 49   cipher, x = 120
# f = 102 ( 31 )  key, t = 116 ( 45 )  modval = 24   cipher, Y = 89
# t = 116 ( 45 )  key, n = 110 ( 39 )  modval = 32   cipher, g = 103
# h = 104 ( 33 )  key, L = 76 ( 11 )  modval = 44   cipher, s = 115
# e = 101 ( 30 )  key, o = 111 ( 40 )  modval = 18   cipher, S = 83
# m = 109 ( 38 )  key, p = 112 ( 41 )  modval = 27   cipher, b = 98
# o = 111 ( 40 )  key, q = 113 ( 42 )  modval = 30   cipher, e = 101
# s = 115 ( 44 )  key, F = 70 ( 5 )  modval = 49   cipher, x = 120
# t = 116 ( 45 )  key, y = 121 ( 50 )  modval = 43   cipher, r = 114
# p = 112 ( 41 )  key, v = 118 ( 47 )  modval = 36   cipher, k = 107
# o = 111 ( 40 )  key, D = 68 ( 3 )  modval = 43   cipher, r = 114
# p = 112 ( 41 )  key, a = 97 ( 26 )  modval = 15   cipher, P = 80
# u = 117 ( 46 )  key, A = 65 ( 0 )  modval = 46   cipher, u = 117
# l = 108 ( 37 )  key, J = 74 ( 9 )  modval = 46   cipher, u = 117
# a = 97 ( 26 )  key, t = 116 ( 45 )  modval = 19   cipher, T = 84
# r = 114 ( 43 )  key, n = 110 ( 39 )  modval = 30   cipher, e = 101
# w = 119 ( 48 )  key, L = 76 ( 11 )  modval = 7   cipher, H = 72
# e = 101 ( 30 )  key, o = 111 ( 40 )  modval = 18   cipher, S = 83
# b = 98 ( 27 )  key, p = 112 ( 41 )  modval = 16   cipher, Q = 81
# s = 115 ( 44 )  key, q = 113 ( 42 )  modval = 34   cipher, i = 105
# i = 105 ( 34 )  key, F = 70 ( 5 )  modval = 39   cipher, n = 110
# t = 116 ( 45 )  key, y = 121 ( 50 )  modval = 43   cipher, r = 114
# e = 101 ( 30 )  key, v = 118 ( 47 )  modval = 25   cipher, Z = 90
# s = 115 ( 44 )  key, D = 68 ( 3 )  modval = 47   cipher, v = 118
# b = 98 ( 27 )  key, a = 97 ( 26 )  modval = 1   cipher, B = 66
# y = 121 ( 50 )  key, A = 65 ( 0 )  modval = 50   cipher, y = 121
# A = 65 ( 0 )  key, J = 74 ( 9 )  modval = 9   cipher, J = 74
# l = 108 ( 37 )  key, t = 116 ( 45 )  modval = 30   cipher, e = 101
# e = 101 ( 30 )  key, n = 110 ( 39 )  modval = 17   cipher, R = 82
# x = 120 ( 49 )  key, L = 76 ( 11 )  modval = 8   cipher, I = 73
# a = 97 ( 26 )  key, o = 111 ( 40 )  modval = 14   cipher, O = 79
# r = 114 ( 43 )  key, p = 112 ( 41 )  modval = 32   cipher, g = 103
# a = 97 ( 26 )  key, q = 113 ( 42 )  modval = 16   cipher, Q = 81
# n = 110 ( 39 )  key, F = 70 ( 5 )  modval = 44   cipher, s = 115
# k = 107 ( 36 )  key, y = 121 ( 50 )  modval = 34   cipher, i = 105
# T = 84 ( 19 )  key, v = 118 ( 47 )  modval = 14   cipher, O = 79
# h = 104 ( 33 )  key, D = 68 ( 3 )  modval = 36   cipher, k = 107
# i = 105 ( 34 )  key, a = 97 ( 26 )  modval = 8   cipher, I = 73
# s = 115 ( 44 )  key, A = 65 ( 0 )  modval = 44   cipher, s = 115
# w = 119 ( 48 )  key, J = 74 ( 9 )  modval = 5   cipher, F = 70
# e = 101 ( 30 )  key, t = 116 ( 45 )  modval = 23   cipher, X = 88
# b = 98 ( 27 )  key, n = 110 ( 39 )  modval = 14   cipher, O = 79
# s = 115 ( 44 )  key, L = 76 ( 11 )  modval = 3   cipher, D = 68
# i = 105 ( 34 )  key, o = 111 ( 40 )  modval = 22   cipher, W = 87
# t = 116 ( 45 )  key, p = 112 ( 41 )  modval = 34   cipher, i = 105
# e = 101 ( 30 )  key, q = 113 ( 42 )  modval = 20   cipher, U = 85
# a = 97 ( 26 )  key, F = 70 ( 5 )  modval = 31   cipher, f = 102
# n = 110 ( 39 )  key, y = 121 ( 50 )  modval = 37   cipher, l = 108
# d = 100 ( 29 )  key, v = 118 ( 47 )  modval = 24   cipher, Y = 89
# t = 116 ( 45 )  key, D = 68 ( 3 )  modval = 48   cipher, w = 119
# h = 104 ( 33 )  key, a = 97 ( 26 )  modval = 7   cipher, H = 72
# e = 101 ( 30 )  key, A = 65 ( 0 )  modval = 30   cipher, e = 101
# s = 115 ( 44 )  key, J = 74 ( 9 )  modval = 1   cipher, B = 66
# o = 111 ( 40 )  key, t = 116 ( 45 )  modval = 33   cipher, h = 104
# f = 102 ( 31 )  key, n = 110 ( 39 )  modval = 18   cipher, S = 83
# t = 116 ( 45 )  key, L = 76 ( 11 )  modval = 4   cipher, E = 69
# w = 119 ( 48 )  key, o = 111 ( 40 )  modval = 36   cipher, k = 107
# a = 97 ( 26 )  key, p = 112 ( 41 )  modval = 15   cipher, P = 80
# r = 114 ( 43 )  key, q = 113 ( 42 )  modval = 33   cipher, h = 104
# e = 101 ( 30 )  key, F = 70 ( 5 )  modval = 35   cipher, j = 106
# i = 105 ( 34 )  key, y = 121 ( 50 )  modval = 32   cipher, g = 103
# t = 116 ( 45 )  key, v = 118 ( 47 )  modval = 40   cipher, o = 111
# r = 114 ( 43 )  key, D = 68 ( 3 )  modval = 46   cipher, u = 117
# u = 117 ( 46 )  key, a = 97 ( 26 )  modval = 20   cipher, U = 85
# n = 110 ( 39 )  key, A = 65 ( 0 )  modval = 39   cipher, n = 110
# s = 115 ( 44 )  key, J = 74 ( 9 )  modval = 1   cipher, B = 66
# o = 111 ( 40 )  key, t = 116 ( 45 )  modval = 33   cipher, h = 104
# n = 110 ( 39 )  key, n = 110 ( 39 )  modval = 26   cipher, a = 97
# w = 119 ( 48 )  key, L = 76 ( 11 )  modval = 7   cipher, H = 72
# e = 101 ( 30 )  key, o = 111 ( 40 )  modval = 18   cipher, S = 83
# r = 114 ( 43 )  key, p = 112 ( 41 )  modval = 32   cipher, g = 103
# e = 101 ( 30 )  key, q = 113 ( 42 )  modval = 20   cipher, U = 85
# c = 99 ( 28 )  key, F = 70 ( 5 )  modval = 33   cipher, h = 104
# r = 114 ( 43 )  key, y = 121 ( 50 )  modval = 41   cipher, p = 112
# e = 101 ( 30 )  key, v = 118 ( 47 )  modval = 25   cipher, Z = 90
# a = 97 ( 26 )  key, D = 68 ( 3 )  modval = 29   cipher, d = 100
# t = 116 ( 45 )  key, a = 97 ( 26 )  modval = 19   cipher, T = 84
# e = 101 ( 30 )  key, A = 65 ( 0 )  modval = 30   cipher, e = 101
# d = 100 ( 29 )  key, J = 74 ( 9 )  modval = 38   cipher, m = 109
# b = 98 ( 27 )  key, t = 116 ( 45 )  modval = 20   cipher, U = 85
# y = 121 ( 50 )  key, n = 110 ( 39 )  modval = 37   cipher, l = 108
# W = 87 ( 22 )  key, L = 76 ( 11 )  modval = 33   cipher, h = 104
# a = 97 ( 26 )  key, o = 111 ( 40 )  modval = 14   cipher, O = 79
# r = 114 ( 43 )  key, p = 112 ( 41 )  modval = 32   cipher, g = 103
# d = 100 ( 29 )  key, q = 113 ( 42 )  modval = 19   cipher, T = 84
# C = 67 ( 2 )  key, F = 70 ( 5 )  modval = 7   cipher, H = 72
# u = 117 ( 46 )  key, y = 121 ( 50 )  modval = 44   cipher, s = 115
# n = 110 ( 39 )  key, v = 118 ( 47 )  modval = 34   cipher, i = 105
# n = 110 ( 39 )  key, D = 68 ( 3 )  modval = 42   cipher, q = 113
# i = 105 ( 34 )  key, a = 97 ( 26 )  modval = 8   cipher, I = 73
# n = 110 ( 39 )  key, A = 65 ( 0 )  modval = 39   cipher, n = 110
# g = 103 ( 32 )  key, J = 74 ( 9 )  modval = 41   cipher, p = 112
# h = 104 ( 33 )  key, t = 116 ( 45 )  modval = 26   cipher, a = 97
# a = 97 ( 26 )  key, n = 110 ( 39 )  modval = 13   cipher, N = 78
# m = 109 ( 38 )  key, L = 76 ( 11 )  modval = 49   cipher, x = 120
# f = 102 ( 31 )  key, o = 111 ( 40 )  modval = 19   cipher, T = 84
# o = 111 ( 40 )  key, p = 112 ( 41 )  modval = 29   cipher, d = 100
# r = 114 ( 43 )  key, q = 113 ( 42 )  modval = 33   cipher, h = 104
# t = 116 ( 45 )  key, F = 70 ( 5 )  modval = 50   cipher, y = 121
# h = 104 ( 33 )  key, y = 121 ( 50 )  modval = 31   cipher, f = 102
# e = 101 ( 30 )  key, v = 118 ( 47 )  modval = 25   cipher, Z = 90
# P = 80 ( 15 )  key, D = 68 ( 3 )  modval = 18   cipher, S = 83
# o = 111 ( 40 )  key, a = 97 ( 26 )  modval = 14   cipher, O = 79
# r = 114 ( 43 )  key, A = 65 ( 0 )  modval = 43   cipher, r = 114
# t = 116 ( 45 )  key, J = 74 ( 9 )  modval = 2   cipher, C = 67
# l = 108 ( 37 )  key, t = 116 ( 45 )  modval = 30   cipher, e = 101
# a = 97 ( 26 )  key, n = 110 ( 39 )  modval = 13   cipher, N = 78
# n = 110 ( 39 )  key, L = 76 ( 11 )  modval = 50   cipher, y = 121
# d = 100 ( 29 )  key, o = 111 ( 40 )  modval = 17   cipher, R = 82
# P = 80 ( 15 )  key, p = 112 ( 41 )  modval = 4   cipher, E = 69
# a = 97 ( 26 )  key, q = 113 ( 42 )  modval = 16   cipher, Q = 81
# t = 116 ( 45 )  key, F = 70 ( 5 )  modval = 50   cipher, y = 121
# t = 116 ( 45 )  key, y = 121 ( 50 )  modval = 43   cipher, r = 114
# e = 101 ( 30 )  key, v = 118 ( 47 )  modval = 25   cipher, Z = 90
# r = 114 ( 43 )  key, D = 68 ( 3 )  modval = 46   cipher, u = 117
# n = 110 ( 39 )  key, a = 97 ( 26 )  modval = 13   cipher, N = 78
# R = 82 ( 17 )  key, A = 65 ( 0 )  modval = 17   cipher, R = 82
# e = 101 ( 30 )  key, J = 74 ( 9 )  modval = 39   cipher, n = 110
# p = 112 ( 41 )  key, t = 116 ( 45 )  modval = 34   cipher, i = 105
# o = 111 ( 40 )  key, n = 110 ( 39 )  modval = 27   cipher, b = 98
# s = 115 ( 44 )  key, L = 76 ( 11 )  modval = 3   cipher, D = 68
# i = 105 ( 34 )  key, o = 111 ( 40 )  modval = 22   cipher, W = 87
# t = 116 ( 45 )  key, p = 112 ( 41 )  modval = 34   cipher, i = 105
# o = 111 ( 40 )  key, q = 113 ( 42 )  modval = 30   cipher, e = 101
# r = 114 ( 43 )  key, F = 70 ( 5 )  modval = 48   cipher, w = 119
# y = 121 ( 50 )  key, y = 121 ( 50 )  modval = 48   cipher, w = 119
# I = 73 ( 8 )  key, v = 118 ( 47 )  modval = 3   cipher, D = 68
# t = 116 ( 45 )  key, D = 68 ( 3 )  modval = 48   cipher, w = 119
# i = 105 ( 34 )  key, a = 97 ( 26 )  modval = 8   cipher, I = 73
# s = 115 ( 44 )  key, A = 65 ( 0 )  modval = 44   cipher, s = 115
# h = 104 ( 33 )  key, J = 74 ( 9 )  modval = 42   cipher, q = 113
# o = 111 ( 40 )  key, t = 116 ( 45 )  modval = 33   cipher, h = 104
# m = 109 ( 38 )  key, n = 110 ( 39 )  modval = 25   cipher, Z = 90
# e = 101 ( 30 )  key, L = 76 ( 11 )  modval = 41   cipher, p = 112
# t = 116 ( 45 )  key, o = 111 ( 40 )  modval = 33   cipher, h = 104
# o = 111 ( 40 )  key, p = 112 ( 41 )  modval = 29   cipher, d = 100
# a = 97 ( 26 )  key, q = 113 ( 42 )  modval = 16   cipher, Q = 81
# n = 110 ( 39 )  key, F = 70 ( 5 )  modval = 44   cipher, s = 115
# I = 73 ( 8 )  key, y = 121 ( 50 )  modval = 6   cipher, G = 71
# n = 110 ( 39 )  key, v = 118 ( 47 )  modval = 34   cipher, i = 105
# f = 102 ( 31 )  key, D = 68 ( 3 )  modval = 34   cipher, i = 105
# o = 111 ( 40 )  key, a = 97 ( 26 )  modval = 14   cipher, O = 79
# r = 114 ( 43 )  key, A = 65 ( 0 )  modval = 43   cipher, r = 114
# m = 109 ( 38 )  key, J = 74 ( 9 )  modval = 47   cipher, v = 118
# a = 97 ( 26 )  key, t = 116 ( 45 )  modval = 19   cipher, T = 84
# l = 108 ( 37 )  key, n = 110 ( 39 )  modval = 24   cipher, Y = 89
# H = 72 ( 7 )  key, L = 76 ( 11 )  modval = 18   cipher, S = 83
# i = 105 ( 34 )  key, o = 111 ( 40 )  modval = 22   cipher, W = 87
# s = 115 ( 44 )  key, p = 112 ( 41 )  modval = 33   cipher, h = 104
# t = 116 ( 45 )  key, q = 113 ( 42 )  modval = 35   cipher, j = 106
# o = 111 ( 40 )  key, F = 70 ( 5 )  modval = 45   cipher, t = 116
# r = 114 ( 43 )  key, y = 121 ( 50 )  modval = 41   cipher, p = 112
# y = 121 ( 50 )  key, v = 118 ( 47 )  modval = 45   cipher, t = 116
# O = 79 ( 14 )  key, D = 68 ( 3 )  modval = 17   cipher, R = 82
# f = 102 ( 31 )  key, a = 97 ( 26 )  modval = 5   cipher, F = 70
# P = 80 ( 15 )  key, A = 65 ( 0 )  modval = 15   cipher, P = 80
# r = 114 ( 43 )  key, J = 74 ( 9 )  modval = 0   cipher, A = 65
# o = 111 ( 40 )  key, t = 116 ( 45 )  modval = 33   cipher, h = 104
# g = 103 ( 32 )  key, n = 110 ( 39 )  modval = 19   cipher, T = 84
# r = 114 ( 43 )  key, L = 76 ( 11 )  modval = 2   cipher, C = 67
# a = 97 ( 26 )  key, o = 111 ( 40 )  modval = 14   cipher, O = 79
# m = 109 ( 38 )  key, p = 112 ( 41 )  modval = 27   cipher, b = 98
# m = 109 ( 38 )  key, q = 113 ( 42 )  modval = 28   cipher, c = 99
# i = 105 ( 34 )  key, F = 70 ( 5 )  modval = 39   cipher, n = 110
# n = 110 ( 39 )  key, y = 121 ( 50 )  modval = 37   cipher, l = 108
# g = 103 ( 32 )  key, v = 118 ( 47 )  modval = 27   cipher, b = 98
# I = 73 ( 8 )  key, D = 68 ( 3 )  modval = 11   cipher, L = 76
# d = 100 ( 29 )  key, a = 97 ( 26 )  modval = 3   cipher, D = 68
# e = 101 ( 30 )  key, A = 65 ( 0 )  modval = 30   cipher, e = 101
# a = 97 ( 26 )  key, J = 74 ( 9 )  modval = 35   cipher, j = 106
# s = 115 ( 44 )  key, t = 116 ( 45 )  modval = 37   cipher, l = 108
# a = 97 ( 26 )  key, n = 110 ( 39 )  modval = 13   cipher, N = 78
# s = 115 ( 44 )  key, L = 76 ( 11 )  modval = 3   cipher, D = 68
# w = 119 ( 48 )  key, o = 111 ( 40 )  modval = 36   cipher, k = 107
# e = 101 ( 30 )  key, p = 112 ( 41 )  modval = 19   cipher, T = 84
# l = 108 ( 37 )  key, q = 113 ( 42 )  modval = 27   cipher, b = 98
# l = 108 ( 37 )  key, F = 70 ( 5 )  modval = 42   cipher, q = 113
# a = 97 ( 26 )  key, y = 121 ( 50 )  modval = 24   cipher, Y = 89
# s = 115 ( 44 )  key, v = 118 ( 47 )  modval = 39   cipher, n = 110
# a = 97 ( 26 )  key, D = 68 ( 3 )  modval = 29   cipher, d = 100
# l = 108 ( 37 )  key, a = 97 ( 26 )  modval = 11   cipher, L = 76
# a = 97 ( 26 )  key, A = 65 ( 0 )  modval = 26   cipher, a = 97
# r = 114 ( 43 )  key, J = 74 ( 9 )  modval = 0   cipher, A = 65
# g = 103 ( 32 )  key, t = 116 ( 45 )  modval = 25   cipher, Z = 90
# e = 101 ( 30 )  key, n = 110 ( 39 )  modval = 17   cipher, R = 82
# v = 118 ( 47 )  key, L = 76 ( 11 )  modval = 6   cipher, G = 71
# o = 111 ( 40 )  key, o = 111 ( 40 )  modval = 28   cipher, c = 99
# l = 108 ( 37 )  key, p = 112 ( 41 )  modval = 26   cipher, a = 97
# u = 117 ( 46 )  key, q = 113 ( 42 )  modval = 36   cipher, k = 107
# m = 109 ( 38 )  key, F = 70 ( 5 )  modval = 43   cipher, r = 114
# e = 101 ( 30 )  key, y = 121 ( 50 )  modval = 28   cipher, c = 99
# o = 111 ( 40 )  key, v = 118 ( 47 )  modval = 35   cipher, j = 106
# f = 102 ( 31 )  key, D = 68 ( 3 )  modval = 34   cipher, i = 105
# m = 109 ( 38 )  key, a = 97 ( 26 )  modval = 12   cipher, M = 77
# a = 97 ( 26 )  key, A = 65 ( 0 )  modval = 26   cipher, a = 97
# t = 116 ( 45 )  key, J = 74 ( 9 )  modval = 2   cipher, C = 67
# e = 101 ( 30 )  key, t = 116 ( 45 )  modval = 23   cipher, X = 88
# r = 114 ( 43 )  key, n = 110 ( 39 )  modval = 30   cipher, e = 101
# i = 105 ( 34 )  key, L = 76 ( 11 )  modval = 45   cipher, t = 116
# a = 97 ( 26 )  key, o = 111 ( 40 )  modval = 14   cipher, O = 79
# l = 108 ( 37 )  key, p = 112 ( 41 )  modval = 26   cipher, a = 97
# r = 114 ( 43 )  key, q = 113 ( 42 )  modval = 33   cipher, h = 104
# e = 101 ( 30 )  key, F = 70 ( 5 )  modval = 35   cipher, j = 106
# c = 99 ( 28 )  key, y = 121 ( 50 )  modval = 26   cipher, a = 97
# o = 111 ( 40 )  key, v = 118 ( 47 )  modval = 35   cipher, j = 106
# r = 114 ( 43 )  key, D = 68 ( 3 )  modval = 46   cipher, u = 117
# d = 100 ( 29 )  key, a = 97 ( 26 )  modval = 3   cipher, D = 68
# i = 105 ( 34 )  key, A = 65 ( 0 )  modval = 34   cipher, i = 105
# n = 110 ( 39 )  key, J = 74 ( 9 )  modval = 48   cipher, w = 119
# g = 103 ( 32 )  key, t = 116 ( 45 )  modval = 25   cipher, Z = 90
# r = 114 ( 43 )  key, n = 110 ( 39 )  modval = 30   cipher, e = 101
# e = 101 ( 30 )  key, L = 76 ( 11 )  modval = 41   cipher, p = 112
# l = 108 ( 37 )  key, o = 111 ( 40 )  modval = 25   cipher, Z = 90
# a = 97 ( 26 )  key, p = 112 ( 41 )  modval = 15   cipher, P = 80
# t = 116 ( 45 )  key, q = 113 ( 42 )  modval = 35   cipher, j = 106
# e = 101 ( 30 )  key, F = 70 ( 5 )  modval = 35   cipher, j = 106
# d = 100 ( 29 )  key, y = 121 ( 50 )  modval = 27   cipher, b = 98
# d = 100 ( 29 )  key, v = 118 ( 47 )  modval = 24   cipher, Y = 89
# i = 105 ( 34 )  key, D = 68 ( 3 )  modval = 37   cipher, l = 108
# s = 115 ( 44 )  key, a = 97 ( 26 )  modval = 18   cipher, S = 83
# c = 99 ( 28 )  key, A = 65 ( 0 )  modval = 28   cipher, c = 99
# o = 111 ( 40 )  key, J = 74 ( 9 )  modval = 49   cipher, x = 120
# u = 117 ( 46 )  key, t = 116 ( 45 )  modval = 39   cipher, n = 110
# r = 114 ( 43 )  key, n = 110 ( 39 )  modval = 30   cipher, e = 101
# s = 115 ( 44 )  key, L = 76 ( 11 )  modval = 3   cipher, D = 68
# e = 101 ( 30 )  key, o = 111 ( 40 )  modval = 18   cipher, S = 83
# s = 115 ( 44 )  key, p = 112 ( 41 )  modval = 33   cipher, h = 104
# a = 97 ( 26 )  key, q = 113 ( 42 )  modval = 16   cipher, Q = 81
# n = 110 ( 39 )  key, F = 70 ( 5 )  modval = 44   cipher, s = 115
# d = 100 ( 29 )  key, y = 121 ( 50 )  modval = 27   cipher, b = 98
# c = 99 ( 28 )  key, v = 118 ( 47 )  modval = 23   cipher, X = 88
# o = 111 ( 40 )  key, D = 68 ( 3 )  modval = 43   cipher, r = 114
# l = 108 ( 37 )  key, a = 97 ( 26 )  modval = 11   cipher, L = 76
# l = 108 ( 37 )  key, A = 65 ( 0 )  modval = 37   cipher, l = 108
# a = 97 ( 26 )  key, J = 74 ( 9 )  modval = 35   cipher, j = 106
# b = 98 ( 27 )  key, t = 116 ( 45 )  modval = 20   cipher, U = 85
# o = 111 ( 40 )  key, n = 110 ( 39 )  modval = 27   cipher, b = 98
# r = 114 ( 43 )  key, L = 76 ( 11 )  modval = 2   cipher, C = 67
# a = 97 ( 26 )  key, o = 111 ( 40 )  modval = 14   cipher, O = 79
# t = 116 ( 45 )  key, p = 112 ( 41 )  modval = 34   cipher, i = 105
# i = 105 ( 34 )  key, q = 113 ( 42 )  modval = 24   cipher, Y = 89
# o = 111 ( 40 )  key, F = 70 ( 5 )  modval = 45   cipher, t = 116
# n = 110 ( 39 )  key, y = 121 ( 50 )  modval = 37   cipher, l = 108
# b = 98 ( 27 )  key, v = 118 ( 47 )  modval = 22   cipher, W = 87
# e = 101 ( 30 )  key, D = 68 ( 3 )  modval = 33   cipher, h = 104
# t = 116 ( 45 )  key, a = 97 ( 26 )  modval = 19   cipher, T = 84
# w = 119 ( 48 )  key, A = 65 ( 0 )  modval = 48   cipher, w = 119
# e = 101 ( 30 )  key, J = 74 ( 9 )  modval = 39   cipher, n = 110
# e = 101 ( 30 )  key, t = 116 ( 45 )  modval = 23   cipher, X = 88
# n = 110 ( 39 )  key, n = 110 ( 39 )  modval = 26   cipher, a = 97
# i = 105 ( 34 )  key, L = 76 ( 11 )  modval = 45   cipher, t = 116
# t = 116 ( 45 )  key, o = 111 ( 40 )  modval = 33   cipher, h = 104
# s = 115 ( 44 )  key, p = 112 ( 41 )  modval = 33   cipher, h = 104
# r = 114 ( 43 )  key, q = 113 ( 42 )  modval = 33   cipher, h = 104
# e = 101 ( 30 )  key, F = 70 ( 5 )  modval = 35   cipher, j = 106
# a = 97 ( 26 )  key, y = 121 ( 50 )  modval = 24   cipher, Y = 89
# d = 100 ( 29 )  key, v = 118 ( 47 )  modval = 24   cipher, Y = 89
# e = 101 ( 30 )  key, D = 68 ( 3 )  modval = 33   cipher, h = 104
# r = 114 ( 43 )  key, a = 97 ( 26 )  modval = 17   cipher, R = 82
# s = 115 ( 44 )  key, A = 65 ( 0 )  modval = 44   cipher, s = 115
# T = 84 ( 19 )  key, J = 74 ( 9 )  modval = 28   cipher, c = 99
# h = 104 ( 33 )  key, t = 116 ( 45 )  modval = 26   cipher, a = 97
# e = 101 ( 30 )  key, n = 110 ( 39 )  modval = 17   cipher, R = 82
# c = 99 ( 28 )  key, L = 76 ( 11 )  modval = 39   cipher, n = 110
# o = 111 ( 40 )  key, o = 111 ( 40 )  modval = 28   cipher, c = 99
# n = 110 ( 39 )  key, p = 112 ( 41 )  modval = 28   cipher, c = 99
# t = 116 ( 45 )  key, q = 113 ( 42 )  modval = 35   cipher, j = 106
# e = 101 ( 30 )  key, F = 70 ( 5 )  modval = 35   cipher, j = 106
# n = 110 ( 39 )  key, y = 121 ( 50 )  modval = 37   cipher, l = 108
# t = 116 ( 45 )  key, v = 118 ( 47 )  modval = 40   cipher, o = 111
# i = 105 ( 34 )  key, D = 68 ( 3 )  modval = 37   cipher, l = 108
# s = 115 ( 44 )  key, a = 97 ( 26 )  modval = 18   cipher, S = 83
# w = 119 ( 48 )  key, A = 65 ( 0 )  modval = 48   cipher, w = 119
# r = 114 ( 43 )  key, J = 74 ( 9 )  modval = 0   cipher, A = 65
# i = 105 ( 34 )  key, t = 116 ( 45 )  modval = 27   cipher, b = 98
# t = 116 ( 45 )  key, n = 110 ( 39 )  modval = 32   cipher, g = 103
# t = 116 ( 45 )  key, L = 76 ( 11 )  modval = 4   cipher, E = 69
# e = 101 ( 30 )  key, o = 111 ( 40 )  modval = 18   cipher, S = 83
# n = 110 ( 39 )  key, p = 112 ( 41 )  modval = 28   cipher, c = 99
# b = 98 ( 27 )  key, q = 113 ( 42 )  modval = 17   cipher, R = 82
# y = 121 ( 50 )  key, F = 70 ( 5 )  modval = 3   cipher, D = 68
# t = 116 ( 45 )  key, y = 121 ( 50 )  modval = 43   cipher, r = 114
# h = 104 ( 33 )  key, v = 118 ( 47 )  modval = 28   cipher, c = 99
# e = 101 ( 30 )  key, D = 68 ( 3 )  modval = 33   cipher, h = 104
# u = 117 ( 46 )  key, a = 97 ( 26 )  modval = 20   cipher, U = 85
# s = 115 ( 44 )  key, A = 65 ( 0 )  modval = 44   cipher, s = 115
# e = 101 ( 30 )  key, J = 74 ( 9 )  modval = 39   cipher, n = 110
# r = 114 ( 43 )  key, t = 116 ( 45 )  modval = 36   cipher, k = 107
# s = 115 ( 44 )  key, n = 110 ( 39 )  modval = 31   cipher, f = 102
# p = 112 ( 41 )  key, L = 76 ( 11 )  modval = 0   cipher, A = 65
# e = 101 ( 30 )  key, o = 111 ( 40 )  modval = 18   cipher, S = 83
# o = 111 ( 40 )  key, p = 112 ( 41 )  modval = 29   cipher, d = 100
# p = 112 ( 41 )  key, q = 113 ( 42 )  modval = 31   cipher, f = 102
# l = 108 ( 37 )  key, F = 70 ( 5 )  modval = 42   cipher, q = 113
# e = 101 ( 30 )  key, y = 121 ( 50 )  modval = 28   cipher, c = 99
# l = 108 ( 37 )  key, v = 118 ( 47 )  modval = 32   cipher, g = 103
# i = 105 ( 34 )  key, D = 68 ( 3 )  modval = 37   cipher, l = 108
# k = 107 ( 36 )  key, a = 97 ( 26 )  modval = 10   cipher, K = 75
# e = 101 ( 30 )  key, A = 65 ( 0 )  modval = 30   cipher, e = 101
# y = 121 ( 50 )  key, J = 74 ( 9 )  modval = 7   cipher, H = 72
# o = 111 ( 40 )  key, t = 116 ( 45 )  modval = 33   cipher, h = 104
# u = 117 ( 46 )  key, n = 110 ( 39 )  modval = 33   cipher, h = 104
# a = 97 ( 26 )  key, L = 76 ( 11 )  modval = 37   cipher, l = 108
# n = 110 ( 39 )  key, o = 111 ( 40 )  modval = 27   cipher, b = 98
# d = 100 ( 29 )  key, p = 112 ( 41 )  modval = 18   cipher, S = 83
# m = 109 ( 38 )  key, q = 113 ( 42 )  modval = 28   cipher, c = 99
# e = 101 ( 30 )  key, F = 70 ( 5 )  modval = 35   cipher, j = 106
# A = 65 ( 0 )  key, y = 121 ( 50 )  modval = 50   cipher, y = 121
# n = 110 ( 39 )  key, v = 118 ( 47 )  modval = 34   cipher, i = 105
# y = 121 ( 50 )  key, D = 68 ( 3 )  modval = 1   cipher, B = 66
# o = 111 ( 40 )  key, a = 97 ( 26 )  modval = 14   cipher, O = 79
# n = 110 ( 39 )  key, A = 65 ( 0 )  modval = 39   cipher, n = 110
# e = 101 ( 30 )  key, J = 74 ( 9 )  modval = 39   cipher, n = 110
# c = 99 ( 28 )  key, t = 116 ( 45 )  modval = 21   cipher, V = 86
# a = 97 ( 26 )  key, n = 110 ( 39 )  modval = 13   cipher, N = 78
# n = 110 ( 39 )  key, L = 76 ( 11 )  modval = 50   cipher, y = 121
# c = 99 ( 28 )  key, o = 111 ( 40 )  modval = 16   cipher, Q = 81
# h = 104 ( 33 )  key, p = 112 ( 41 )  modval = 22   cipher, W = 87
# a = 97 ( 26 )  key, q = 113 ( 42 )  modval = 16   cipher, Q = 81
# n = 110 ( 39 )  key, F = 70 ( 5 )  modval = 44   cipher, s = 115
# g = 103 ( 32 )  key, y = 121 ( 50 )  modval = 30   cipher, e = 101
# e = 101 ( 30 )  key, v = 118 ( 47 )  modval = 25   cipher, Z = 90
# a = 97 ( 26 )  key, D = 68 ( 3 )  modval = 29   cipher, d = 100
# n = 110 ( 39 )  key, a = 97 ( 26 )  modval = 13   cipher, N = 78
# y = 121 ( 50 )  key, A = 65 ( 0 )  modval = 50   cipher, y = 121
# p = 112 ( 41 )  key, J = 74 ( 9 )  modval = 50   cipher, y = 121
# a = 97 ( 26 )  key, t = 116 ( 45 )  modval = 19   cipher, T = 84
# g = 103 ( 32 )  key, n = 110 ( 39 )  modval = 19   cipher, T = 84
# e = 101 ( 30 )  key, L = 76 ( 11 )  modval = 41   cipher, p = 112
# o = 111 ( 40 )  key, o = 111 ( 40 )  modval = 28   cipher, c = 99
# r = 114 ( 43 )  key, p = 112 ( 41 )  modval = 32   cipher, g = 103
# c = 99 ( 28 )  key, q = 113 ( 42 )  modval = 18   cipher, S = 83
# r = 114 ( 43 )  key, F = 70 ( 5 )  modval = 48   cipher, w = 119
# e = 101 ( 30 )  key, y = 121 ( 50 )  modval = 28   cipher, c = 99
# a = 97 ( 26 )  key, v = 118 ( 47 )  modval = 21   cipher, V = 86
# t = 116 ( 45 )  key, D = 68 ( 3 )  modval = 48   cipher, w = 119
# e = 101 ( 30 )  key, a = 97 ( 26 )  modval = 4   cipher, E = 69
# n = 110 ( 39 )  key, A = 65 ( 0 )  modval = 39   cipher, n = 110
# e = 101 ( 30 )  key, J = 74 ( 9 )  modval = 39   cipher, n = 110
# w = 119 ( 48 )  key, t = 116 ( 45 )  modval = 41   cipher, p = 112
# p = 112 ( 41 )  key, n = 110 ( 39 )  modval = 28   cipher, c = 99
# a = 97 ( 26 )  key, L = 76 ( 11 )  modval = 37   cipher, l = 108
# g = 103 ( 32 )  key, o = 111 ( 40 )  modval = 20   cipher, U = 85
# e = 101 ( 30 )  key, p = 112 ( 41 )  modval = 19   cipher, T = 84
# s = 115 ( 44 )  key, q = 113 ( 42 )  modval = 34   cipher, i = 105
# R = 82 ( 17 )  key, F = 70 ( 5 )  modval = 22   cipher, W = 87
# e = 101 ( 30 )  key, y = 121 ( 50 )  modval = 28   cipher, c = 99
# a = 97 ( 26 )  key, v = 118 ( 47 )  modval = 21   cipher, V = 86
# d = 100 ( 29 )  key, D = 68 ( 3 )  modval = 32   cipher, g = 103
# t = 116 ( 45 )  key, a = 97 ( 26 )  modval = 19   cipher, T = 84
# h = 104 ( 33 )  key, A = 65 ( 0 )  modval = 33   cipher, h = 104
# e = 101 ( 30 )  key, J = 74 ( 9 )  modval = 39   cipher, n = 110
# T = 84 ( 19 )  key, t = 116 ( 45 )  modval = 12   cipher, M = 77
# e = 101 ( 30 )  key, n = 110 ( 39 )  modval = 17   cipher, R = 82
# x = 120 ( 49 )  key, L = 76 ( 11 )  modval = 8   cipher, I = 73
# t = 116 ( 45 )  key, o = 111 ( 40 )  modval = 33   cipher, h = 104
# F = 70 ( 5 )  key, p = 112 ( 41 )  modval = 46   cipher, u = 117
# o = 111 ( 40 )  key, q = 113 ( 42 )  modval = 30   cipher, e = 101
# r = 114 ( 43 )  key, F = 70 ( 5 )  modval = 48   cipher, w = 119
# m = 109 ( 38 )  key, y = 121 ( 50 )  modval = 36   cipher, k = 107
# a = 97 ( 26 )  key, v = 118 ( 47 )  modval = 21   cipher, V = 86
# t = 116 ( 45 )  key, D = 68 ( 3 )  modval = 48   cipher, w = 119
# t = 116 ( 45 )  key, a = 97 ( 26 )  modval = 19   cipher, T = 84
# i = 105 ( 34 )  key, A = 65 ( 0 )  modval = 34   cipher, i = 105
# n = 110 ( 39 )  key, J = 74 ( 9 )  modval = 48   cipher, w = 119
# g = 103 ( 32 )  key, t = 116 ( 45 )  modval = 25   cipher, Z = 90
# R = 82 ( 17 )  key, n = 110 ( 39 )  modval = 4   cipher, E = 69
# u = 117 ( 46 )  key, L = 76 ( 11 )  modval = 5   cipher, F = 70
# l = 108 ( 37 )  key, o = 111 ( 40 )  modval = 25   cipher, Z = 90
# e = 101 ( 30 )  key, p = 112 ( 41 )  modval = 19   cipher, T = 84
# s = 115 ( 44 )  key, q = 113 ( 42 )  modval = 34   cipher, i = 105
# t = 116 ( 45 )  key, F = 70 ( 5 )  modval = 50   cipher, y = 121
# o = 111 ( 40 )  key, y = 121 ( 50 )  modval = 38   cipher, m = 109
# f = 102 ( 31 )  key, v = 118 ( 47 )  modval = 26   cipher, a = 97
# i = 105 ( 34 )  key, D = 68 ( 3 )  modval = 37   cipher, l = 108
# n = 110 ( 39 )  key, a = 97 ( 26 )  modval = 13   cipher, N = 78
# d = 100 ( 29 )  key, A = 65 ( 0 )  modval = 29   cipher, d = 100
# o = 111 ( 40 )  key, J = 74 ( 9 )  modval = 49   cipher, x = 120
# u = 117 ( 46 )  key, t = 116 ( 45 )  modval = 39   cipher, n = 110
# t = 116 ( 45 )  key, n = 110 ( 39 )  modval = 32   cipher, g = 103
# h = 104 ( 33 )  key, L = 76 ( 11 )  modval = 44   cipher, s = 115
# o = 111 ( 40 )  key, o = 111 ( 40 )  modval = 28   cipher, c = 99
# w = 119 ( 48 )  key, p = 112 ( 41 )  modval = 37   cipher, l = 108
# a = 97 ( 26 )  key, q = 113 ( 42 )  modval = 16   cipher, Q = 81
# n = 110 ( 39 )  key, F = 70 ( 5 )  modval = 44   cipher, s = 115
# d = 100 ( 29 )  key, y = 121 ( 50 )  modval = 27   cipher, b = 98
# t = 116 ( 45 )  key, v = 118 ( 47 )  modval = 40   cipher, o = 111
# h = 104 ( 33 )  key, D = 68 ( 3 )  modval = 36   cipher, k = 107
# e = 101 ( 30 )  key, a = 97 ( 26 )  modval = 4   cipher, E = 69
# n = 110 ( 39 )  key, A = 65 ( 0 )  modval = 39   cipher, n = 110
# g = 103 ( 32 )  key, J = 74 ( 9 )  modval = 41   cipher, p = 112
# o = 111 ( 40 )  key, t = 116 ( 45 )  modval = 33   cipher, h = 104
# t = 116 ( 45 )  key, n = 110 ( 39 )  modval = 32   cipher, g = 103
# o = 111 ( 40 )  key, L = 76 ( 11 )  modval = 51   cipher, z = 122
# t = 116 ( 45 )  key, o = 111 ( 40 )  modval = 33   cipher, h = 104
# h = 104 ( 33 )  key, p = 112 ( 41 )  modval = 22   cipher, W = 87
# e = 101 ( 30 )  key, q = 113 ( 42 )  modval = 20   cipher, U = 85
# W = 87 ( 22 )  key, F = 70 ( 5 )  modval = 27   cipher, b = 98
# i = 105 ( 34 )  key, y = 121 ( 50 )  modval = 32   cipher, g = 103
# k = 107 ( 36 )  key, v = 118 ( 47 )  modval = 31   cipher, f = 102
# i = 105 ( 34 )  key, D = 68 ( 3 )  modval = 37   cipher, l = 108
# W = 87 ( 22 )  key, a = 97 ( 26 )  modval = 48   cipher, w = 119
# i = 105 ( 34 )  key, A = 65 ( 0 )  modval = 34   cipher, i = 105
# k = 107 ( 36 )  key, J = 74 ( 9 )  modval = 45   cipher, t = 116
# i = 105 ( 34 )  key, t = 116 ( 45 )  modval = 27   cipher, b = 98
# S = 83 ( 18 )  key, n = 110 ( 39 )  modval = 5   cipher, F = 70
# a = 97 ( 26 )  key, L = 76 ( 11 )  modval = 37   cipher, l = 108
# n = 110 ( 39 )  key, o = 111 ( 40 )  modval = 27   cipher, b = 98
# d = 100 ( 29 )  key, p = 112 ( 41 )  modval = 18   cipher, S = 83
# b = 98 ( 27 )  key, q = 113 ( 42 )  modval = 17   cipher, R = 82
# o = 111 ( 40 )  key, F = 70 ( 5 )  modval = 45   cipher, t = 116
# x = 120 ( 49 )  key, y = 121 ( 50 )  modval = 47   cipher, v = 118
# t = 116 ( 45 )  key, v = 118 ( 47 )  modval = 40   cipher, o = 111
# o = 111 ( 40 )  key, D = 68 ( 3 )  modval = 43   cipher, r = 114
# t = 116 ( 45 )  key, a = 97 ( 26 )  modval = 19   cipher, T = 84
# r = 114 ( 43 )  key, A = 65 ( 0 )  modval = 43   cipher, r = 114
# y = 121 ( 50 )  key, J = 74 ( 9 )  modval = 7   cipher, H = 72
# i = 105 ( 34 )  key, t = 116 ( 45 )  modval = 27   cipher, b = 98
# t = 116 ( 45 )  key, n = 110 ( 39 )  modval = 32   cipher, g = 103
# y = 121 ( 50 )  key, L = 76 ( 11 )  modval = 9   cipher, J = 74
# o = 111 ( 40 )  key, o = 111 ( 40 )  modval = 28   cipher, c = 99
# u = 117 ( 46 )  key, p = 112 ( 41 )  modval = 35   cipher, j = 106
# r = 114 ( 43 )  key, q = 113 ( 42 )  modval = 33   cipher, h = 104
# s = 115 ( 44 )  key, F = 70 ( 5 )  modval = 49   cipher, x = 120
# e = 101 ( 30 )  key, y = 121 ( 50 )  modval = 28   cipher, c = 99
# l = 108 ( 37 )  key, v = 118 ( 47 )  modval = 32   cipher, g = 103
# f = 102 ( 31 )  key, D = 68 ( 3 )  modval = 34   cipher, i = 105
# P = 80 ( 15 )  key, a = 97 ( 26 )  modval = 41   cipher, p = 112
# l = 108 ( 37 )  key, A = 65 ( 0 )  modval = 37   cipher, l = 108
# e = 101 ( 30 )  key, J = 74 ( 9 )  modval = 39   cipher, n = 110
# a = 97 ( 26 )  key, t = 116 ( 45 )  modval = 19   cipher, T = 84
# s = 115 ( 44 )  key, n = 110 ( 39 )  modval = 31   cipher, f = 102
# e = 101 ( 30 )  key, L = 76 ( 11 )  modval = 41   cipher, p = 112
# u = 117 ( 46 )  key, o = 111 ( 40 )  modval = 34   cipher, i = 105
# s = 115 ( 44 )  key, p = 112 ( 41 )  modval = 33   cipher, h = 104
# e = 101 ( 30 )  key, q = 113 ( 42 )  modval = 20   cipher, U = 85
# t = 116 ( 45 )  key, F = 70 ( 5 )  modval = 50   cipher, y = 121
# h = 104 ( 33 )  key, y = 121 ( 50 )  modval = 31   cipher, f = 102
# e = 101 ( 30 )  key, v = 118 ( 47 )  modval = 25   cipher, Z = 90
# W = 87 ( 22 )  key, D = 68 ( 3 )  modval = 25   cipher, Z = 90
# i = 105 ( 34 )  key, a = 97 ( 26 )  modval = 8   cipher, I = 73
# k = 107 ( 36 )  key, A = 65 ( 0 )  modval = 36   cipher, k = 107
# i = 105 ( 34 )  key, J = 74 ( 9 )  modval = 43   cipher, r = 114
# W = 87 ( 22 )  key, t = 116 ( 45 )  modval = 15   cipher, P = 80
# i = 105 ( 34 )  key, n = 110 ( 39 )  modval = 21   cipher, V = 86
# k = 107 ( 36 )  key, L = 76 ( 11 )  modval = 47   cipher, v = 118
# i = 105 ( 34 )  key, o = 111 ( 40 )  modval = 22   cipher, W = 87
# S = 83 ( 18 )  key, p = 112 ( 41 )  modval = 7   cipher, H = 72
# a = 97 ( 26 )  key, q = 113 ( 42 )  modval = 16   cipher, Q = 81
# n = 110 ( 39 )  key, F = 70 ( 5 )  modval = 44   cipher, s = 115
# d = 100 ( 29 )  key, y = 121 ( 50 )  modval = 27   cipher, b = 98
# b = 98 ( 27 )  key, v = 118 ( 47 )  modval = 22   cipher, W = 87
# o = 111 ( 40 )  key, D = 68 ( 3 )  modval = 43   cipher, r = 114
# x = 120 ( 49 )  key, a = 97 ( 26 )  modval = 23   cipher, X = 88
# i = 105 ( 34 )  key, A = 65 ( 0 )  modval = 34   cipher, i = 105
# f = 102 ( 31 )  key, J = 74 ( 9 )  modval = 40   cipher, o = 111
# y = 121 ( 50 )  key, t = 116 ( 45 )  modval = 43   cipher, r = 114
# o = 111 ( 40 )  key, n = 110 ( 39 )  modval = 27   cipher, b = 98
# ...
# e = 101 ( 30 )  key, J = 74 ( 9 )  modval = 39   cipher, n = 110
# n = 110 ( 39 )  key, t = 116 ( 45 )  modval = 32   cipher, g = 103
# t = 116 ( 45 )  key, n = 110 ( 39 )  modval = 32   cipher, g = 103
# c = 99 ( 28 )  key, L = 76 ( 11 )  modval = 39   cipher, n = 110
# a = 97 ( 26 )  key, o = 111 ( 40 )  modval = 14   cipher, O = 79
# n = 110 ( 39 )  key, p = 112 ( 41 )  modval = 28   cipher, c = 99
# b = 98 ( 27 )  key, q = 113 ( 42 )  modval = 17   cipher, R = 82
# e = 101 ( 30 )  key, F = 70 ( 5 )  modval = 35   cipher, j = 106
# e = 101 ( 30 )  key, y = 121 ( 50 )  modval = 28   cipher, c = 99
# d = 100 ( 29 )  key, v = 118 ( 47 )  modval = 24   cipher, Y = 89
# i = 105 ( 34 )  key, D = 68 ( 3 )  modval = 37   cipher, l = 108
# t = 116 ( 45 )  key, a = 97 ( 26 )  modval = 19   cipher, T = 84
# e = 101 ( 30 )  key, A = 65 ( 0 )  modval = 30   cipher, e = 101
# d = 100 ( 29 )  key, J = 74 ( 9 )  modval = 38   cipher, m = 109
# b = 98 ( 27 )  key, t = 116 ( 45 )  modval = 20   cipher, U = 85
# y = 121 ( 50 )  key, n = 110 ( 39 )  modval = 37   cipher, l = 108
# a = 97 ( 26 )  key, L = 76 ( 11 )  modval = 37   cipher, l = 108
# n = 110 ( 39 )  key, o = 111 ( 40 )  modval = 27   cipher, b = 98
# y = 121 ( 50 )  key, p = 112 ( 41 )  modval = 39   cipher, n = 110
# p = 112 ( 41 )  key, q = 113 ( 42 )  modval = 31   cipher, f = 102
# e = 101 ( 30 )  key, F = 70 ( 5 )  modval = 35   cipher, j = 106
# r = 114 ( 43 )  key, y = 121 ( 50 )  modval = 41   cipher, p = 112
# s = 115 ( 44 )  key, v = 118 ( 47 )  modval = 39   cipher, n = 110
# o = 111 ( 40 )  key, D = 68 ( 3 )  modval = 43   cipher, r = 114
# n = 110 ( 39 )  key, a = 97 ( 26 )  modval = 13   cipher, N = 78
# A = 65 ( 0 )  key, A = 65 ( 0 )  modval = 0   cipher, A = 65
# l = 108 ( 37 )  key, J = 74 ( 9 )  modval = 46   cipher, u = 117
# l = 108 ( 37 )  key, t = 116 ( 45 )  modval = 30   cipher, e = 101
# o = 111 ( 40 )  key, n = 110 ( 39 )  modval = 27   cipher, b = 98
# t = 116 ( 45 )  key, L = 76 ( 11 )  modval = 4   cipher, E = 69
# h = 104 ( 33 )  key, o = 111 ( 40 )  modval = 21   cipher, V = 86
# e = 101 ( 30 )  key, p = 112 ( 41 )  modval = 19   cipher, T = 84
# r = 114 ( 43 )  key, q = 113 ( 42 )  modval = 33   cipher, h = 104
# w = 119 ( 48 )  key, F = 70 ( 5 )  modval = 1   cipher, B = 66
# i = 105 ( 34 )  key, y = 121 ( 50 )  modval = 32   cipher, g = 103
# k = 107 ( 36 )  key, v = 118 ( 47 )  modval = 31   cipher, f = 102
# i = 105 ( 34 )  key, D = 68 ( 3 )  modval = 37   cipher, l = 108
# s = 115 ( 44 )  key, a = 97 ( 26 )  modval = 18   cipher, S = 83
# i = 105 ( 34 )  key, A = 65 ( 0 )  modval = 34   cipher, i = 105
# n = 110 ( 39 )  key, J = 74 ( 9 )  modval = 48   cipher, w = 119
# c = 99 ( 28 )  key, t = 116 ( 45 )  modval = 21   cipher, V = 86
# l = 108 ( 37 )  key, n = 110 ( 39 )  modval = 24   cipher, Y = 89
# u = 117 ( 46 )  key, L = 76 ( 11 )  modval = 5   cipher, F = 70
# d = 100 ( 29 )  key, o = 111 ( 40 )  modval = 17   cipher, R = 82
# i = 105 ( 34 )  key, p = 112 ( 41 )  modval = 23   cipher, X = 88
# n = 110 ( 39 )  key, q = 113 ( 42 )  modval = 29   cipher, d = 100
# g = 103 ( 32 )  key, F = 70 ( 5 )  modval = 37   cipher, l = 108
# W = 87 ( 22 )  key, y = 121 ( 50 )  modval = 20   cipher, U = 85
# i = 105 ( 34 )  key, v = 118 ( 47 )  modval = 29   cipher, d = 100
# k = 107 ( 36 )  key, D = 68 ( 3 )  modval = 39   cipher, n = 110
# i = 105 ( 34 )  key, a = 97 ( 26 )  modval = 8   cipher, I = 73
# p = 112 ( 41 )  key, A = 65 ( 0 )  modval = 41   cipher, p = 112
# e = 101 ( 30 )  key, J = 74 ( 9 )  modval = 39   cipher, n = 110
# d = 100 ( 29 )  key, t = 116 ( 45 )  modval = 22   cipher, W = 87
# i = 105 ( 34 )  key, n = 110 ( 39 )  modval = 21   cipher, V = 86
# a = 97 ( 26 )  key, L = 76 ( 11 )  modval = 37   cipher, l = 108
# a = 97 ( 26 )  key, o = 111 ( 40 )  modval = 14   cipher, O = 79
# n = 110 ( 39 )  key, p = 112 ( 41 )  modval = 28   cipher, c = 99
# d = 100 ( 29 )  key, q = 113 ( 42 )  modval = 19   cipher, T = 84
# W = 87 ( 22 )  key, F = 70 ( 5 )  modval = 27   cipher, b = 98
# i = 105 ( 34 )  key, y = 121 ( 50 )  modval = 32   cipher, g = 103
# k = 107 ( 36 )  key, v = 118 ( 47 )  modval = 31   cipher, f = 102
# i = 105 ( 34 )  key, D = 68 ( 3 )  modval = 37   cipher, l = 108
# q = 113 ( 42 )  key, a = 97 ( 26 )  modval = 16   cipher, Q = 81
# u = 117 ( 46 )  key, A = 65 ( 0 )  modval = 46   cipher, u = 117
# o = 111 ( 40 )  key, J = 74 ( 9 )  modval = 49   cipher, x = 120
# t = 116 ( 45 )  key, t = 116 ( 45 )  modval = 38   cipher, m = 109
# e = 101 ( 30 )  key, n = 110 ( 39 )  modval = 17   cipher, R = 82
# a = 97 ( 26 )  key, L = 76 ( 11 )  modval = 37   cipher, l = 108
# n = 110 ( 39 )  key, o = 111 ( 40 )  modval = 27   cipher, b = 98
# d = 100 ( 29 )  key, p = 112 ( 41 )  modval = 18   cipher, S = 83
# W = 87 ( 22 )  key, q = 113 ( 42 )  modval = 12   cipher, M = 77
# i = 105 ( 34 )  key, F = 70 ( 5 )  modval = 39   cipher, n = 110
# k = 107 ( 36 )  key, y = 121 ( 50 )  modval = 34   cipher, i = 105
# t = 116 ( 45 )  key, v = 118 ( 47 )  modval = 40   cipher, o = 111
# i = 105 ( 34 )  key, D = 68 ( 3 )  modval = 37   cipher, l = 108
# o = 111 ( 40 )  key, a = 97 ( 26 )  modval = 14   cipher, O = 79
# n = 110 ( 39 )  key, A = 65 ( 0 )  modval = 39   cipher, n = 110
# a = 97 ( 26 )  key, J = 74 ( 9 )  modval = 35   cipher, j = 106
# r = 114 ( 43 )  key, t = 116 ( 45 )  modval = 36   cipher, k = 107
# y = 121 ( 50 )  key, n = 110 ( 39 )  modval = 37   cipher, l = 108
# a = 97 ( 26 )  key, L = 76 ( 11 )  modval = 37   cipher, l = 108
# r = 114 ( 43 )  key, o = 111 ( 40 )  modval = 31   cipher, f = 102
# e = 101 ( 30 )  key, p = 112 ( 41 )  modval = 19   cipher, T = 84
# d = 100 ( 29 )  key, q = 113 ( 42 )  modval = 19   cipher, T = 84
# e = 101 ( 30 )  key, F = 70 ( 5 )  modval = 35   cipher, j = 106
# s = 115 ( 44 )  key, y = 121 ( 50 )  modval = 42   cipher, q = 113
# c = 99 ( 28 )  key, v = 118 ( 47 )  modval = 23   cipher, X = 88
# e = 101 ( 30 )  key, D = 68 ( 3 )  modval = 33   cipher, h = 104
# n = 110 ( 39 )  key, a = 97 ( 26 )  modval = 13   cipher, N = 78
# d = 100 ( 29 )  key, A = 65 ( 0 )  modval = 29   cipher, d = 100
# e = 101 ( 30 )  key, J = 74 ( 9 )  modval = 39   cipher, n = 110
# d = 100 ( 29 )  key, t = 116 ( 45 )  modval = 22   cipher, W = 87
# f = 102 ( 31 )  key, n = 110 ( 39 )  modval = 18   cipher, S = 83
# r = 114 ( 43 )  key, L = 76 ( 11 )  modval = 2   cipher, C = 67
# o = 111 ( 40 )  key, o = 111 ( 40 )  modval = 28   cipher, c = 99
# m = 109 ( 38 )  key, p = 112 ( 41 )  modval = 27   cipher, b = 98
# i = 105 ( 34 )  key, q = 113 ( 42 )  modval = 24   cipher, Y = 89
# t = 116 ( 45 )  key, F = 70 ( 5 )  modval = 50   cipher, y = 121
# W = 87 ( 22 )  key, y = 121 ( 50 )  modval = 20   cipher, U = 85
# i = 105 ( 34 )  key, v = 118 ( 47 )  modval = 29   cipher, d = 100
# k = 107 ( 36 )  key, D = 68 ( 3 )  modval = 39   cipher, n = 110
# i = 105 ( 34 )  key, a = 97 ( 26 )  modval = 8   cipher, I = 73
# p = 112 ( 41 )  key, A = 65 ( 0 )  modval = 41   cipher, p = 112
# e = 101 ( 30 )  key, J = 74 ( 9 )  modval = 39   cipher, n = 110
# d = 100 ( 29 )  key, t = 116 ( 45 )  modval = 22   cipher, W = 87
# i = 105 ( 34 )  key, n = 110 ( 39 )  modval = 21   cipher, V = 86
# a = 97 ( 26 )  key, L = 76 ( 11 )  modval = 37   cipher, l = 108
# i = 105 ( 34 )  key, o = 111 ( 40 )  modval = 22   cipher, W = 87
# s = 115 ( 44 )  key, p = 112 ( 41 )  modval = 33   cipher, h = 104
# n = 110 ( 39 )  key, q = 113 ( 42 )  modval = 29   cipher, d = 100
# o = 111 ( 40 )  key, F = 70 ( 5 )  modval = 45   cipher, t = 116
# w = 119 ( 48 )  key, y = 121 ( 50 )  modval = 46   cipher, u = 117
# t = 116 ( 45 )  key, v = 118 ( 47 )  modval = 40   cipher, o = 111
# h = 104 ( 33 )  key, D = 68 ( 3 )  modval = 36   cipher, k = 107
# e = 101 ( 30 )  key, a = 97 ( 26 )  modval = 4   cipher, E = 69
# f = 102 ( 31 )  key, A = 65 ( 0 )  modval = 31   cipher, f = 102
# i = 105 ( 34 )  key, J = 74 ( 9 )  modval = 43   cipher, r = 114
# f = 102 ( 31 )  key, t = 116 ( 45 )  modval = 24   cipher, Y = 89
# t = 116 ( 45 )  key, n = 110 ( 39 )  modval = 32   cipher, g = 103
# h = 104 ( 33 )  key, L = 76 ( 11 )  modval = 44   cipher, s = 115
# m = 109 ( 38 )  key, o = 111 ( 40 )  modval = 26   cipher, a = 97
# o = 111 ( 40 )  key, p = 112 ( 41 )  modval = 29   cipher, d = 100
# s = 115 ( 44 )  key, q = 113 ( 42 )  modval = 34   cipher, i = 105
# t = 116 ( 45 )  key, F = 70 ( 5 )  modval = 50   cipher, y = 121
# v = 118 ( 47 )  key, y = 121 ( 50 )  modval = 45   cipher, t = 116
# i = 105 ( 34 )  key, v = 118 ( 47 )  modval = 29   cipher, d = 100
# s = 115 ( 44 )  key, D = 68 ( 3 )  modval = 47   cipher, v = 118
# i = 105 ( 34 )  key, a = 97 ( 26 )  modval = 8   cipher, I = 73
# t = 116 ( 45 )  key, A = 65 ( 0 )  modval = 45   cipher, t = 116
# e = 101 ( 30 )  key, J = 74 ( 9 )  modval = 39   cipher, n = 110
# d = 100 ( 29 )  key, t = 116 ( 45 )  modval = 22   cipher, W = 87
# w = 119 ( 48 )  key, n = 110 ( 39 )  modval = 35   cipher, j = 106
# e = 101 ( 30 )  key, L = 76 ( 11 )  modval = 41   cipher, p = 112
# b = 98 ( 27 )  key, o = 111 ( 40 )  modval = 15   cipher, P = 80
# s = 115 ( 44 )  key, p = 112 ( 41 )  modval = 33   cipher, h = 104
# i = 105 ( 34 )  key, q = 113 ( 42 )  modval = 24   cipher, Y = 89
# t = 116 ( 45 )  key, F = 70 ( 5 )  modval = 50   cipher, y = 121
# e = 101 ( 30 )  key, y = 121 ( 50 )  modval = 28   cipher, c = 99
# a = 97 ( 26 )  key, v = 118 ( 47 )  modval = 21   cipher, V = 86
# c = 99 ( 28 )  key, D = 68 ( 3 )  modval = 31   cipher, f = 102
# c = 99 ( 28 )  key, a = 97 ( 26 )  modval = 2   cipher, C = 67
# o = 111 ( 40 )  key, A = 65 ( 0 )  modval = 40   cipher, o = 111
# r = 114 ( 43 )  key, J = 74 ( 9 )  modval = 0   cipher, A = 65
# d = 100 ( 29 )  key, t = 116 ( 45 )  modval = 22   cipher, W = 87
# i = 105 ( 34 )  key, n = 110 ( 39 )  modval = 21   cipher, V = 86
# n = 110 ( 39 )  key, L = 76 ( 11 )  modval = 50   cipher, y = 121
# g = 103 ( 32 )  key, o = 111 ( 40 )  modval = 20   cipher, U = 85
# t = 116 ( 45 )  key, p = 112 ( 41 )  modval = 34   cipher, i = 105
# o = 111 ( 40 )  key, q = 113 ( 42 )  modval = 30   cipher, e = 101
# A = 65 ( 0 )  key, F = 70 ( 5 )  modval = 5   cipher, F = 70
# l = 108 ( 37 )  key, y = 121 ( 50 )  modval = 35   cipher, j = 106
# e = 101 ( 30 )  key, v = 118 ( 47 )  modval = 25   cipher, Z = 90
# x = 120 ( 49 )  key, D = 68 ( 3 )  modval = 0   cipher, A = 65
# a = 97 ( 26 )  key, a = 97 ( 26 )  modval = 0   cipher, A = 65
# R = 82 ( 17 )  key, A = 65 ( 0 )  modval = 17   cipher, R = 82
# a = 97 ( 26 )  key, J = 74 ( 9 )  modval = 35   cipher, j = 106
# n = 110 ( 39 )  key, t = 116 ( 45 )  modval = 32   cipher, g = 103
# k = 107 ( 36 )  key, n = 110 ( 39 )  modval = 23   cipher, X = 88
# C = 67 ( 2 )  key, L = 76 ( 11 )  modval = 13   cipher, N = 78
# a = 97 ( 26 )  key, o = 111 ( 40 )  modval = 14   cipher, O = 79
# p = 112 ( 41 )  key, p = 112 ( 41 )  modval = 30   cipher, e = 101
# i = 105 ( 34 )  key, q = 113 ( 42 )  modval = 24   cipher, Y = 89
# t = 116 ( 45 )  key, F = 70 ( 5 )  modval = 50   cipher, y = 121
# a = 97 ( 26 )  key, y = 121 ( 50 )  modval = 24   cipher, Y = 89
# l = 108 ( 37 )  key, v = 118 ( 47 )  modval = 32   cipher, g = 103
# L = 76 ( 11 )  key, D = 68 ( 3 )  modval = 14   cipher, O = 79
# e = 101 ( 30 )  key, a = 97 ( 26 )  modval = 4   cipher, E = 69
# t = 116 ( 45 )  key, A = 65 ( 0 )  modval = 45   cipher, t = 116
# t = 116 ( 45 )  key, J = 74 ( 9 )  modval = 2   cipher, C = 67
# e = 101 ( 30 )  key, t = 116 ( 45 )  modval = 23   cipher, X = 88
# r = 114 ( 43 )  key, n = 110 ( 39 )  modval = 30   cipher, e = 101
# s = 115 ( 44 )  key, L = 76 ( 11 )  modval = 3   cipher, D = 68
# i = 105 ( 34 )  key, o = 111 ( 40 )  modval = 22   cipher, W = 87
# s = 115 ( 44 )  key, p = 112 ( 41 )  modval = 33   cipher, h = 104
# a = 97 ( 26 )  key, q = 113 ( 42 )  modval = 16   cipher, Q = 81
# s = 115 ( 44 )  key, F = 70 ( 5 )  modval = 49   cipher, x = 120
# o = 111 ( 40 )  key, y = 121 ( 50 )  modval = 38   cipher, m = 109
# n = 110 ( 39 )  key, v = 118 ( 47 )  modval = 34   cipher, i = 105
# g = 103 ( 32 )  key, D = 68 ( 3 )  modval = 35   cipher, j = 106
# b = 98 ( 27 )  key, a = 97 ( 26 )  modval = 1   cipher, B = 66
# y = 121 ( 50 )  key, A = 65 ( 0 )  modval = 50   cipher, y = 121
# A = 65 ( 0 )  key, J = 74 ( 9 )  modval = 9   cipher, J = 74
# m = 109 ( 38 )  key, t = 116 ( 45 )  modval = 31   cipher, f = 102
# e = 101 ( 30 )  key, n = 110 ( 39 )  modval = 17   cipher, R = 82
# r = 114 ( 43 )  key, L = 76 ( 11 )  modval = 2   cipher, C = 67
# i = 105 ( 34 )  key, o = 111 ( 40 )  modval = 22   cipher, W = 87
# c = 99 ( 28 )  key, p = 112 ( 41 )  modval = 17   cipher, R = 82
# a = 97 ( 26 )  key, q = 113 ( 42 )  modval = 16   cipher, Q = 81
# n = 110 ( 39 )  key, F = 70 ( 5 )  modval = 44   cipher, s = 115
# s = 115 ( 44 )  key, y = 121 ( 50 )  modval = 42   cipher, q = 113
# i = 105 ( 34 )  key, v = 118 ( 47 )  modval = 29   cipher, d = 100
# n = 110 ( 39 )  key, D = 68 ( 3 )  modval = 42   cipher, q = 113
# g = 103 ( 32 )  key, a = 97 ( 26 )  modval = 6   cipher, G = 71
# e = 101 ( 30 )  key, A = 65 ( 0 )  modval = 30   cipher, e = 101
# r = 114 ( 43 )  key, J = 74 ( 9 )  modval = 0   cipher, A = 65
# H = 72 ( 7 )  key, t = 116 ( 45 )  modval = 0   cipher, A = 65
# a = 97 ( 26 )  key, n = 110 ( 39 )  modval = 13   cipher, N = 78
# i = 105 ( 34 )  key, L = 76 ( 11 )  modval = 45   cipher, t = 116
# l = 108 ( 37 )  key, o = 111 ( 40 )  modval = 25   cipher, Z = 90
# e = 101 ( 30 )  key, p = 112 ( 41 )  modval = 19   cipher, T = 84
# e = 101 ( 30 )  key, q = 113 ( 42 )  modval = 20   cipher, U = 85
# S = 83 ( 18 )  key, F = 70 ( 5 )  modval = 23   cipher, X = 88
# t = 116 ( 45 )  key, y = 121 ( 50 )  modval = 43   cipher, r = 114
# e = 101 ( 30 )  key, v = 118 ( 47 )  modval = 25   cipher, Z = 90
# i = 105 ( 34 )  key, D = 68 ( 3 )  modval = 37   cipher, l = 108
# n = 110 ( 39 )  key, a = 97 ( 26 )  modval = 13   cipher, N = 78
# f = 102 ( 31 )  key, A = 65 ( 0 )  modval = 31   cipher, f = 102
# e = 101 ( 30 )  key, J = 74 ( 9 )  modval = 39   cipher, n = 110
# l = 108 ( 37 )  key, t = 116 ( 45 )  modval = 30   cipher, e = 101
# d = 100 ( 29 )  key, n = 110 ( 39 )  modval = 16   cipher, Q = 81
# a = 97 ( 26 )  key, L = 76 ( 11 )  modval = 37   cipher, l = 108
# n = 110 ( 39 )  key, o = 111 ( 40 )  modval = 27   cipher, b = 98
# d = 100 ( 29 )  key, p = 112 ( 41 )  modval = 18   cipher, S = 83
# A = 65 ( 0 )  key, q = 113 ( 42 )  modval = 42   cipher, q = 113
# m = 109 ( 38 )  key, F = 70 ( 5 )  modval = 43   cipher, r = 114
# e = 101 ( 30 )  key, y = 121 ( 50 )  modval = 28   cipher, c = 99
# r = 114 ( 43 )  key, v = 118 ( 47 )  modval = 38   cipher, m = 109
# i = 105 ( 34 )  key, D = 68 ( 3 )  modval = 37   cipher, l = 108
# c = 99 ( 28 )  key, a = 97 ( 26 )  modval = 2   cipher, C = 67
# a = 97 ( 26 )  key, A = 65 ( 0 )  modval = 26   cipher, a = 97
# n = 110 ( 39 )  key, J = 74 ( 9 )  modval = 48   cipher, w = 119
# r = 114 ( 43 )  key, t = 116 ( 45 )  modval = 36   cipher, k = 107
# e = 101 ( 30 )  key, n = 110 ( 39 )  modval = 17   cipher, R = 82
# c = 99 ( 28 )  key, L = 76 ( 11 )  modval = 39   cipher, n = 110
# o = 111 ( 40 )  key, o = 111 ( 40 )  modval = 28   cipher, c = 99
# r = 114 ( 43 )  key, p = 112 ( 41 )  modval = 32   cipher, g = 103
# d = 100 ( 29 )  key, q = 113 ( 42 )  modval = 19   cipher, T = 84
# p = 112 ( 41 )  key, F = 70 ( 5 )  modval = 46   cipher, u = 117
# r = 114 ( 43 )  key, y = 121 ( 50 )  modval = 41   cipher, p = 112
# o = 111 ( 40 )  key, v = 118 ( 47 )  modval = 35   cipher, j = 106
# d = 100 ( 29 )  key, D = 68 ( 3 )  modval = 32   cipher, g = 103
# u = 117 ( 46 )  key, a = 97 ( 26 )  modval = 20   cipher, U = 85
# c = 99 ( 28 )  key, A = 65 ( 0 )  modval = 28   cipher, c = 99
# e = 101 ( 30 )  key, J = 74 ( 9 )  modval = 39   cipher, n = 110
# r = 114 ( 43 )  key, t = 116 ( 45 )  modval = 36   cipher, k = 107
# B = 66 ( 1 )  key, n = 110 ( 39 )  modval = 40   cipher, o = 111
# l = 108 ( 37 )  key, L = 76 ( 11 )  modval = 48   cipher, w = 119
# o = 111 ( 40 )  key, o = 111 ( 40 )  modval = 28   cipher, c = 99
# o = 111 ( 40 )  key, p = 112 ( 41 )  modval = 29   cipher, d = 100
# d = 100 ( 29 )  key, q = 113 ( 42 )  modval = 19   cipher, T = 84
# P = 80 ( 15 )  key, F = 70 ( 5 )  modval = 20   cipher, U = 85
# o = 111 ( 40 )  key, y = 121 ( 50 )  modval = 38   cipher, m = 109
# p = 112 ( 41 )  key, v = 118 ( 47 )  modval = 36   cipher, k = 107
# End of file

# %%
#DECRYPTION
fileout = open("/home/saklain/CryptoLab/vegout.txt","w")

file = open("key.txt","r") 
key=file.readline()[:-1]

idx=0

with open("/home/saklain/CryptoLab/cip.txt","r") as f:
    while True:
        ch = f.read(1)
        if not ch:
              print("End of file")
              break
        if ch=='\n':
            fileout.write(str('\n'))
            continue
        if ch==' ':
            fileout.write(str(' '))
            continue
        
        #print("**********")
        
        cipidx = ord(ch)
        if(cipidx>90):
            cipidx-=6
        cipidx-=65
        
        
        #print("key ",key[idx])
        keyidx = ord(key[idx])

        if(keyidx>90):
            keyidx-=6
        keyidx-=65
        
        temp=idx
        
        idx+=1
        if(idx==len(key)):
            idx=0
            

        newidx = 52 + cipidx - keyidx 
        
        
        temp2= newidx
        
        if(newidx>=52):
            newidx-=52
        
        
        newidx+=65
        
        if(newidx>90):
            newidx+=6
                    
        fileout.write(str(chr(newidx)))
        #print(newidx,chr(newidx))
        
        
        
fileout.close()
# Out:
# End of file

# %%
file = open("key.txt","r") 
key=file.readline()[:-1]
#temp = [line[:-1] for line in file]

print(key)
print(len(key))
#print(key[10])
# Out:
# aAJtnLopqFyvD
# 13
